# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/Insight-Sogang-Univ/insight-15th/blob/main/advanced/template/session05/practice_generativemodel.ipynb" target="_parent">
#       <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
#     </a>
#   </td>
# </table>

# %% [markdown]
# ## 📁 라이브러리 임포트
# - AutoEncoder, VAE, GAN은 tensorflow를 사용합니다.
# - Diffusion Model은 torch를 사용합니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

import time
from tqdm.notebook import trange
from tqdm.keras import TqdmCallback
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Model

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
import copy

# %% [markdown]
# ## 🧮 GPU 사용하기

# %%
# PyTorch GPU 상태
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"✅ [PyTorch] Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU name: {torch.cuda.get_device_name(0)}")


# TensorFlow GPU 상태
print("\n✅ [TensorFlow] GPU Devices:")
print(tf.config.list_physical_devices('GPU'))
# Out:
# ✅ [PyTorch] Using device: cuda
# GPU name: Tesla T4
#
# ✅ [TensorFlow] GPU Devices:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # ✍🏻 생성 모델 실습

# %% [markdown]
# Fashion MNIST 의류 이미지 데이터를 사용하여 3가지 생성 모델을 실습해봅시다!
#
# 1. **AutoEncoder (오토인코더)** — 입력 이미지를 압축 후 복원
# 2. **GAN (Generative Adversarial Network)** — 가짜 이미지를 생성
# 3. **Diffusion Model** — 노이즈로부터 이미지를 복원

# %% [markdown]
# ## 🔍 1. AutoEncoder(오토인코더)
# Fashion MNIST 의류 이미지를 압축(784차원 → 32차원)했다가 복원하는 오토인코더를 작성해 봅시다!

# %% [markdown]
# ### 1-1.  데이터 준비
# - 입력데이터 준비. Fashion MNIST 의류 이미지를 사용하며, 정답레이블은 사용하지 않습니다.
# - 모든값은 0~1사이로 정규화하고 28x28이미지를 크기 784x1의 벡터로 만듭니다.

# %%
## Fashion MNIST 데이터 로드
(x_train, _), (x_test, _) = tf.keras.datasets.fashion_mnist.load_data()

# 정규화 및 reshape
x_train = x_train.astype('float32')/255.
x_test = x_test.astype('float32')/255.
x_train = x_train.*******((-1, 28, 28, 1))      #reshape()를 호출해 훈련데이터를 (배치크기, 28, 28, 1)로 설정합니다.
x_test = x_test.*******((-1, 28, 28, 1))


print("훈련 데이터:", x_train.shape)
print("테스트 데이터:", x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# 훈련 데이터: (60000, 28, 28, 1)
# 테스트 데이터: (10000, 28, 28, 1)

# %% [markdown]
# ### 1-2. AutoEncoder 모델 정의

# %%
# Conv2D 기반 오토인코더 구조입니다.
# 인코더: Conv2D + MaxPooling2D 로 특징 추출
# 디코더: Conv2D + UpSampling2D 로 이미지 복원
input_img = tf.keras.layers.Input(shape=(28, 28, 1))

# 인코더
x = tf.keras.layers.Conv2D(32, (3, 3), activation='****', padding='same')(input_img)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# 디코더
x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(encoded)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
decoded = tf.keras.layers.Conv2D(1, (3, 3), activation='*******', padding='same')(x)  # 출력 픽셀값을 [0,1]로 제한하기 위해 sigmoid 사용 (입력 데이터 정규화가 [0,1]인 경우)

autoencoder = tf.keras.Model(input_img, decoded)

# %%
#모델컴파일. 먼저 화소당 MSE손실을 사용하고, optimizer로 'adam'을 사용합니다.
autoencoder.compile(optimizer='****', loss=tf.keras.losses.MeanSquaredError())

# %% [markdown]
# ### 1-3. AutoEncoder 학습
# - 이제 오토인코더를 50에폭동안 학습시켜봅시다.

# %%
# ✅ 에폭별 재구성 이미지 시각화 콜백
class VisualizeCallback(tf.keras.callbacks.Callback):
    def __init__(self, x_sample, every=10):
        self.x_sample = x_sample
        self.every = every
    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.every == 0:
            decoded = self.model.predict(self.x_sample, verbose=0)
            n = len(self.x_sample)
            fig, axes = plt.subplots(2, n, figsize=(n * 2, 4))
            for i in range(n):
                axes[0, i].imshow(self.x_sample[i].reshape(28, 28), cmap='gray')
                axes[0, i].axis('off')
                axes[1, i].imshow(decoded[i].reshape(28, 28), cmap='gray')
                axes[1, i].axis('off')
            axes[0, 0].set_ylabel('원본', fontsize=9)
            axes[1, 0].set_ylabel('재구성', fontsize=9)
            plt.suptitle(f'AE Epoch {epoch+1}', fontsize=12, fontweight='bold')
            plt.tight_layout()
            plt.show()

# ✅ Early Stopping: val_loss 기준, patience=5
#    restore_best_weights=True → 조기 종료 시 가장 좋았던 가중치로 자동 복원
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# ✅ ModelCheckpoint: val_loss 최소일 때 자동 저장
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    'best_autoencoder.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

history = autoencoder.fit(
    x_train, *_*****,       #x_train, x_test, y_train, y_test 중 어떤것이들어갈까요?
    epochs=50,
    batch_size=256,
    shuffle=True,
    validation_data=(x_test, x_test),
    verbose=0,
    callbacks=[TqdmCallback(verbose=1),
               VisualizeCallback(x_test[:8], every=10),
               early_stop,
               checkpoint_cb]
)
print('✅ 최적 AE 가중치가 best_autoencoder.keras 에 저장됐습니다.')
# Out:
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# Epoch 1: val_loss improved from None to 0.01270, saving model to best_autoencoder.keras
#
# Epoch 1: finished saving model to best_autoencoder.keras
#
# Epoch 2: val_loss improved from 0.01270 to 0.00994, saving model to best_autoencoder.keras
#
# Epoch 2: finished saving model to best_autoencoder.keras
#
# Epoch 3: val_loss improved from 0.00994 to 0.00847, saving model to best_autoencoder.keras
#
# Epoch 3: finished saving model to best_autoencoder.keras
#
# Epoch 4: val_loss improved from 0.00847 to 0.00738, saving model to best_autoencoder.keras
#
# Epoch 4: finished saving model to best_autoencoder.keras
#
# Epoch 5: val_loss improved from 0.00738 to 0.00663, saving model to best_autoencoder.keras
#
# Epoch 5: finished saving model to best_autoencoder.keras
#
# Epoch 6: val_loss improved from 0.00663 to 0.00588, saving model to best_autoencoder.keras
#
# Epoch 6: finished saving model to best_autoencoder.keras
#
# Epoch 7: val_loss improved from 0.00588 to 0.00536, saving model to best_autoencoder.keras
#
# Epoch 7: finished saving model to best_autoencoder.keras
#
# Epoch 8: val_loss improved from 0.00536 to 0.00514, saving model to best_autoencoder.keras
#
# Epoch 8: finished saving model to best_autoencoder.keras
#
# Epoch 9: val_loss improved from 0.00514 to 0.00459, saving model to best_autoencoder.keras
#
# Epoch 9: finished saving model to best_autoencoder.keras
# Epoch 10: val_loss did not improve from 0.00459
#
# Epoch 11: val_loss improved from 0.00459 to 0.00414, saving model to best_autoencoder.keras
#
# Epoch 11: finished saving model to best_autoencoder.keras
#
# Epoch 12: val_loss improved from 0.00414 to 0.00402, saving model to best_autoencoder.keras
#
# Epoch 12: finished saving model to best_autoencoder.keras
#
# Epoch 13: val_loss improved from 0.00402 to 0.00385, saving model to best_autoencoder.keras
#
# Epoch 13: finished saving model to best_autoencoder.keras
#
# Epoch 14: val_loss improved from 0.00385 to 0.00372, saving model to best_autoencoder.keras
#
# Epoch 14: finished saving model to best_autoencoder.keras
#
# Epoch 15: val_loss improved from 0.00372 to 0.00355, saving model to best_autoencoder.keras
#
# Epoch 15: finished saving model to best_autoencoder.keras
#
# Epoch 16: val_loss improved from 0.00355 to 0.00355, saving model to best_autoencoder.keras
#
# Epoch 16: finished saving model to best_autoencoder.keras
#
# Epoch 17: val_loss improved from 0.00355 to 0.00336, saving model to best_autoencoder.keras
#
# Epoch 17: finished saving model to best_autoencoder.keras
#
# Epoch 18: val_loss did not improve from 0.00336
#
# Epoch 19: val_loss improved from 0.00336 to 0.00320, saving model to best_autoencoder.keras
#
# Epoch 19: finished saving model to best_autoencoder.keras
# Epoch 20: val_loss did not improve from 0.00320
#
# Epoch 21: val_loss improved from 0.00320 to 0.00317, saving model to best_autoencoder.keras
#
# Epoch 21: finished saving model to best_autoencoder.keras
#
# Epoch 22: val_loss improved from 0.00317 to 0.00305, saving model to best_autoencoder.keras
#
# Epoch 22: finished saving model to best_autoencoder.keras
#
# Epoch 23: val_loss did not improve from 0.00305
#
# Epoch 24: val_loss improved from 0.00305 to 0.00294, saving model to best_autoencoder.keras
#
# Epoch 24: finished saving model to best_autoencoder.keras
#
# Epoch 25: val_loss improved from 0.00294 to 0.00292, saving model to best_autoencoder.keras
#
# Epoch 25: finished saving model to best_autoencoder.keras
#
# Epoch 26: val_loss improved from 0.00292 to 0.00288, saving model to best_autoencoder.keras
#
# Epoch 26: finished saving model to best_autoencoder.keras
#
# Epoch 27: val_loss improved from 0.00288 to 0.00280, saving model to best_autoencoder.keras
#
# Epoch 27: finished saving model to best_autoencoder.keras
#
# Epoch 28: val_loss improved from 0.00280 to 0.00278, saving model to best_autoencoder.keras
#
# Epoch 28: finished saving model to best_autoencoder.keras
#
# Epoch 29: val_loss improved from 0.00278 to 0.00275, saving model to best_autoencoder.keras
#
# Epoch 29: finished saving model to best_autoencoder.keras
# Epoch 30: val_loss improved from 0.00275 to 0.00272, saving model to best_autoencoder.keras
#
# Epoch 30: finished saving model to best_autoencoder.keras
#
# Epoch 31: val_loss did not improve from 0.00272
#
# Epoch 32: val_loss improved from 0.00272 to 0.00264, saving model to best_autoencoder.keras
#
# Epoch 32: finished saving model to best_autoencoder.keras
#
# Epoch 33: val_loss improved from 0.00264 to 0.00258, saving model to best_autoencoder.keras
#
# Epoch 33: finished saving model to best_autoencoder.keras
#
# Epoch 34: val_loss did not improve from 0.00258
#
# Epoch 35: val_loss improved from 0.00258 to 0.00253, saving model to best_autoencoder.keras
#
# Epoch 35: finished saving model to best_autoencoder.keras
#
# Epoch 36: val_loss did not improve from 0.00253
#
# Epoch 37: val_loss improved from 0.00253 to 0.00249, saving model to best_autoencoder.keras
#
# Epoch 37: finished saving model to best_autoencoder.keras
#
# Epoch 38: val_loss did not improve from 0.00249
#
# Epoch 39: val_loss did not improve from 0.00249
# Epoch 40: val_loss improved from 0.00249 to 0.00246, saving model to best_autoencoder.keras
#
# Epoch 40: finished saving model to best_autoencoder.keras
#
# Epoch 41: val_loss did not improve from 0.00246
#
# Epoch 42: val_loss improved from 0.00246 to 0.00243, saving model to best_autoencoder.keras
#
# Epoch 42: finished saving model to best_autoencoder.keras
#
# Epoch 43: val_loss improved from 0.00243 to 0.00239, saving model to best_autoencoder.keras
#
# Epoch 43: finished saving model to best_autoencoder.keras
#
# Epoch 44: val_loss improved from 0.00239 to 0.00235, saving model to best_autoencoder.keras
#
# Epoch 44: finished saving model to best_autoencoder.keras
#
# Epoch 45: val_loss improved from 0.00235 to 0.00230, saving model to best_autoencoder.keras
#
# Epoch 45: finished saving model to best_autoencoder.keras
#
# Epoch 46: val_loss did not improve from 0.00230
#
# Epoch 47: val_loss improved from 0.00230 to 0.00228, saving model to best_autoencoder.keras
#
# Epoch 47: finished saving model to best_autoencoder.keras
#
# Epoch 48: val_loss did not improve from 0.00228
#
# Epoch 49: val_loss improved from 0.00228 to 0.00223, saving model to best_autoencoder.keras
#
# Epoch 49: finished saving model to best_autoencoder.keras
# Epoch 50: val_loss improved from 0.00223 to 0.00222, saving model to best_autoencoder.keras
#
# Epoch 50: finished saving model to best_autoencoder.keras
# Restoring model weights from the end of the best epoch: 50.
# ✅ 최적 AE 가중치가 best_autoencoder.keras 에 저장됐습니다.

# %%
# ✅ AE 학습 수렴 곡선
plt.figure(figsize=(8, 4))
plt.plot(history.history['loss'],     label='Train Loss', color='royalblue')
plt.plot(history.history['val_loss'], label='Val Loss',   color='tomato', linestyle='--')
plt.xlabel('Epoch'); plt.ylabel('MSE Loss')
plt.title('AutoEncoder – Training Loss Curve')
plt.legend(); plt.tight_layout(); plt.show()

# %% [markdown]
# #### **💡 Loss 곡선이 우하향할수록 모델이 잘 수렴하고 있다는 뜻입니다.**
#
# Train/Val Loss 차이가 크면 과적합(Overfitting)을 의심해볼 수 있습니다.

# %% [markdown]
# ### 1-4. 재복원 결과 시각화
# - 이제는 맷플롯립을 이용해 x_test에 포함된 원본이미지와 재복원된 이미지를 화면에 그려봅시다.

# %%
decoded_imgs = autoencoder.predict(*_****)  # 어떤데이터를 예측해야할까요?

n=10
plt.figure(figsize=(20, 6))
for i in range(1, n+1):
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28,28), cmap='gray')    #원본이미지

    ax = plt.subplot(2, n, i +n )
    plt.imshow(decoded_imgs[i].reshape(28,28), cmap='gray')   # 재구성된 이미지
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %% [markdown]
# #### **💡 윗줄은 원래 의류 이미지고, 아랫줄은 재구성된 의류 이미지입니다!**
#
# ![image.png](data:image/png;base64,...)
#
# 생각보다 잘됐죠? 전 잘됐는데... 안 됐으면 안타깝게 됐네요!

# %% [markdown]
# ## 🔍 2. VAE

# %% [markdown]
# - VAE로도 Fashion MNIST 데이터의 이미지를 복원해볼까요?

# %% [markdown]
# ### 2-1. 데이터 준비

# %%
# Fashion MNIST 데이터 로드
(x_train, _), (x_test, _) = tf.keras.datasets.fashion_mnist.load_data()

# 정규화 및 reshape
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0
x_train = x_train.*******((-1, 28, 28, 1))
x_test = x_test.*******((-1, 28, 28, 1))

print("훈련 데이터:", x_train.shape)
print("테스트 데이터:", x_test.shape)
# Out:
# 훈련 데이터: (60000, 28, 28, 1)
# 테스트 데이터: (10000, 28, 28, 1)

# %% [markdown]
# ### 2-2. VAE 모델 정의

# %%
latent_dim = 32  # 잠재 공간 차원 (Fashion MNIST의 복잡도를 반영해 32로 설정)

# %%
# ----- 인코더 -----
encoder_inputs = layers.Input(shape=(28, 28, 1))
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(128, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)

# %% [markdown]
# VAE의 목적은 입력 $X$를 확률 분포 $P(z|X)$를 따르는 잠재 벡터 $z$로 인코딩하는 것입니다.
#
# 이 과정에서 $z$를 샘플링하게 되는데, 일반적인 무작위 샘플링은 역전파(Backpropagation)를 통해 모델의 가중치를 업데이트할 수 없다는 문제가 있습니다.
#
# 재매개변수화 트릭은 이 문제를 해결하여 $z$를 생성하는 과정에 '무작위성(Randomness)'을 유지하면서도 '미분 가능성(Differentiability)'을 확보합니다.

# %%
# 재매개변수화 트릭


def sampling(args):
    z_****, z_log_*** = args.      #z의 평균과 로그분산을 샘플링합니다!
    eps = tf.******.normal(shape=(tf.shape(z_mean)[0], latent_dim))   # 무작위성을 줍시다! 무작위는영어로?
    return z_mean + tf.exp(0.5 * z_log_var) * eps   # return값이 잠재벡터 z의 공식이 됩니다.

z = layers.Lambda(sampling, name="z")([z_mean, z_log_var])
encoder = Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 28, 28, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 14, 14,    │        320 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 7, 7, 64)  │     18,496 │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 3136)      │          0 │ conv2d_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    401,536 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 32)        │      4,128 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 32)        │      4,128 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z (Lambda)          │ (None, 32)        │          0 │ z_mean[0][0],     │
# │                     │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 428,608 (1.64 MB)
#  Trainable params: 428,608 (1.64 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ----- 디코더 -----
latent_inputs = layers.Input(shape=(latent_dim,))
x = layers.Dense(7 * 7 * 128, activation="relu")(latent_inputs)
x = layers.Reshape((7, 7, 128))(x)
x = layers.Conv2DTranspose(128, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2D(1, 3, activation="sigmoid", padding="same")(x)
decoder = Model(latent_******, decoder_*******, name="decoder")  # 디코더의 입력과 출력 변수를 넣어주세요!
decoder.summary()
# Out:
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6272)           │       206,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 14, 14, 128)    │       147,584 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 28, 28, 64)     │        73,792 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 28, 28, 1)      │           577 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 428,929 (1.64 MB)
#  Trainable params: 428,929 (1.64 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 2-3. VAE 클래스 정의

# %%
class VAE(Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder

    def compile(self, optimizer, **kwargs):
        super(VAE, self).compile(**kwargs)
        self.optimizer = optimizer

        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        self.recon_loss_tracker = tf.keras.metrics.Mean(name="recon_loss")
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.recon_loss_tracker,
            self.kl_loss_tracker,
        ]

    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        return self.decoder(z)

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            # 재구성 손실 (픽셀별 MSE)
            recon_loss = tf.reduce_mean(
                tf.reduce_sum(tf.square(data - reconstruction), axis=[1,2,3])
            )
            # KL 손실
            kl_loss = -0.5 * tf.reduce_mean(
                tf.reduce_sum(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=1)
            )
            total_loss = recon_loss + kl_loss

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        self.total_loss_tracker.update_state(total_loss)
        self.recon_loss_tracker.update_state(recon_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "recon_loss": self.recon_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %% [markdown]
# ### 2-4. VAE 학습

# %%
# 모델 생성
vae = VAE(encoder, decoder)
vae.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=lambda x, y: 0.0  # validation용 dummy loss
)

# %%
# ✅ 에폭별 VAE 생성 이미지 시각화 콜백
class VAEVisualCallback(tf.keras.callbacks.Callback):
    def __init__(self, decoder, every=10):
        self.decoder = decoder
        self.every = every
    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.every == 0:
            z_samples = tf.random.normal(shape=(8, latent_dim))
            generated  = self.decoder.predict(z_samples, verbose=0)
            fig, axes  = plt.subplots(1, 8, figsize=(16, 2))
            for i, ax in enumerate(axes):
                ax.imshow(generated[i].reshape(28, 28), cmap='gray')
                ax.axis('off')
            plt.suptitle(f'VAE Epoch {epoch+1} – Generated Samples',
                         fontsize=12, fontweight='bold')
            plt.tight_layout()
            plt.show()

# ✅ Early Stopping
vae_early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='loss',
    mode='min',
    patience=5,
    restore_best_weights=True,
    verbose=1
)


# ✅ ModelCheckpoint
vae_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    'best_vae_weights.weights.h5',
    monitor='loss',
    mode='min',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)


# 학습
history = vae.***(              #학습
    x_train,
    epochs=30,
    batch_size=128,
    validation_data=(x_test, *_****) # x_train, x_test, y_train, y_test중 어떤게 들어갈까요?,
    callbacks=[VAEVisualCallback(decoder, every=10),
               vae_early_stop,
               vae_checkpoint_cb]
)
print('✅ 최적 VAE 가중치가 best_vae.keras 에 저장됐습니다.')
# Out:
# Epoch 1/30
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.2193 - loss: 24.3593 - recon_loss: 16.1400
# Epoch 1: loss improved from None to 24.43007, saving model to best_vae_weights.weights.h5
#
# Epoch 1: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.2362 - loss: 24.4301 - recon_loss: 16.1939 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 2/30
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.2182 - loss: 24.4120 - recon_loss: 16.1938
# Epoch 2: loss improved from 24.43007 to 24.40187, saving model to best_vae_weights.weights.h5
#
# Epoch 2: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - kl_loss: 8.2382 - loss: 24.4019 - recon_loss: 16.1637 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 3/30
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.2372 - loss: 24.3405 - recon_loss: 16.1033
# Epoch 3: loss improved from 24.40187 to 24.36734, saving model to best_vae_weights.weights.h5
#
# Epoch 3: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.2447 - loss: 24.3673 - recon_loss: 16.1226 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 4/30
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.2997 - loss: 24.3284 - recon_loss: 16.0287
# Epoch 4: loss improved from 24.36734 to 24.32757, saving model to best_vae_weights.weights.h5
#
# Epoch 4: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.2683 - loss: 24.3276 - recon_loss: 16.0593 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 5/30
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - kl_loss: 8.2482 - loss: 24.2902 - recon_loss: 16.0420
# Epoch 5: loss improved from 24.32757 to 24.29214, saving model to best_vae_weights.weights.h5
#
# Epoch 5: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.2545 - loss: 24.2921 - recon_loss: 16.0377 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 6/30
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - kl_loss: 8.2650 - loss: 24.1997 - recon_loss: 15.9346
# Epoch 6: loss improved from 24.29214 to 24.23988, saving model to best_vae_weights.weights.h5
#
# Epoch 6: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.2705 - loss: 24.2399 - recon_loss: 15.9694 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 7/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - kl_loss: 8.2628 - loss: 24.1863 - recon_loss: 15.9236
# Epoch 7: loss improved from 24.23988 to 24.22067, saving model to best_vae_weights.weights.h5
#
# Epoch 7: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.2747 - loss: 24.2207 - recon_loss: 15.9460 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 8/30
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3034 - loss: 24.2057 - recon_loss: 15.9024
# Epoch 8: loss improved from 24.22067 to 24.17916, saving model to best_vae_weights.weights.h5
#
# Epoch 8: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.2926 - loss: 24.1792 - recon_loss: 15.8865 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 9/30
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.2853 - loss: 24.1562 - recon_loss: 15.8709
# Epoch 9: loss improved from 24.17916 to 24.13037, saving model to best_vae_weights.weights.h5
#
# Epoch 9: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.2767 - loss: 24.1304 - recon_loss: 15.8537 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 10/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3092 - loss: 24.1258 - recon_loss: 15.8166
# Epoch 10: loss improved from 24.13037 to 24.12493, saving model to best_vae_weights.weights.h5
#
# Epoch 10: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - kl_loss: 8.2988 - loss: 24.1249 - recon_loss: 15.8262 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 11/30
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.2834 - loss: 24.0977 - recon_loss: 15.8143
# Epoch 11: loss improved from 24.12493 to 24.07337, saving model to best_vae_weights.weights.h5
#
# Epoch 11: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - kl_loss: 8.2890 - loss: 24.0734 - recon_loss: 15.7843 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 12/30
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3312 - loss: 24.0428 - recon_loss: 15.7116
# Epoch 12: loss improved from 24.07337 to 24.06412, saving model to best_vae_weights.weights.h5
#
# Epoch 12: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.3066 - loss: 24.0641 - recon_loss: 15.7575 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 13/30
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3117 - loss: 24.0513 - recon_loss: 15.7396
# Epoch 13: loss improved from 24.06412 to 24.04819, saving model to best_vae_weights.weights.h5
#
# Epoch 13: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - kl_loss: 8.3220 - loss: 24.0482 - recon_loss: 15.7262 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 14/30
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3044 - loss: 24.0062 - recon_loss: 15.7018
# Epoch 14: loss improved from 24.04819 to 23.99992, saving model to best_vae_weights.weights.h5
#
# Epoch 14: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.3057 - loss: 23.9999 - recon_loss: 15.6943 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 15/30
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - kl_loss: 8.3265 - loss: 23.9405 - recon_loss: 15.6140
# Epoch 15: loss improved from 23.99992 to 23.96791, saving model to best_vae_weights.weights.h5
#
# Epoch 15: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - kl_loss: 8.3271 - loss: 23.9679 - recon_loss: 15.6408 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 16/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - kl_loss: 8.3184 - loss: 23.9037 - recon_loss: 15.5853
# Epoch 16: loss improved from 23.96791 to 23.94049, saving model to best_vae_weights.weights.h5
#
# Epoch 16: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - kl_loss: 8.3155 - loss: 23.9405 - recon_loss: 15.6250 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 17/30
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - kl_loss: 8.3241 - loss: 23.9552 - recon_loss: 15.6311
# Epoch 17: loss improved from 23.94049 to 23.93815, saving model to best_vae_weights.weights.h5
#
# Epoch 17: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.3312 - loss: 23.9381 - recon_loss: 15.6070 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 18/30
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3089 - loss: 23.8639 - recon_loss: 15.5550
# Epoch 18: loss improved from 23.93815 to 23.88721, saving model to best_vae_weights.weights.h5
#
# Epoch 18: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.3274 - loss: 23.8872 - recon_loss: 15.5598 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 19/30
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3258 - loss: 23.9009 - recon_loss: 15.5751
# Epoch 19: loss improved from 23.88721 to 23.86748, saving model to best_vae_weights.weights.h5
#
# Epoch 19: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.3270 - loss: 23.8675 - recon_loss: 15.5405 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 20/30
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3637 - loss: 23.8880 - recon_loss: 15.5243
# Epoch 20: loss improved from 23.86748 to 23.86388, saving model to best_vae_weights.weights.h5
#
# Epoch 20: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.3520 - loss: 23.8639 - recon_loss: 15.5118 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 21/30
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3511 - loss: 23.8123 - recon_loss: 15.4612
# Epoch 21: loss improved from 23.86388 to 23.84900, saving model to best_vae_weights.weights.h5
#
# Epoch 21: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.3400 - loss: 23.8490 - recon_loss: 15.5090 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 22/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3372 - loss: 23.7738 - recon_loss: 15.4366
# Epoch 22: loss improved from 23.84900 to 23.80461, saving model to best_vae_weights.weights.h5
#
# Epoch 22: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - kl_loss: 8.3502 - loss: 23.8046 - recon_loss: 15.4544 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 23/30
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3611 - loss: 23.8242 - recon_loss: 15.4631
# Epoch 23: loss improved from 23.80461 to 23.79121, saving model to best_vae_weights.weights.h5
#
# Epoch 23: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.3575 - loss: 23.7912 - recon_loss: 15.4338 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 24/30
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3564 - loss: 23.7433 - recon_loss: 15.3869
# Epoch 24: loss improved from 23.79121 to 23.78957, saving model to best_vae_weights.weights.h5
#
# Epoch 24: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - kl_loss: 8.3620 - loss: 23.7896 - recon_loss: 15.4276 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 25/30
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3787 - loss: 23.7726 - recon_loss: 15.3939
# Epoch 25: loss improved from 23.78957 to 23.75658, saving model to best_vae_weights.weights.h5
#
# Epoch 25: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.3715 - loss: 23.7566 - recon_loss: 15.3851 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 26/30
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3475 - loss: 23.7561 - recon_loss: 15.4086
# Epoch 26: loss improved from 23.75658 to 23.70879, saving model to best_vae_weights.weights.h5
#
# Epoch 26: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - kl_loss: 8.3529 - loss: 23.7088 - recon_loss: 15.3559 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 27/30
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3440 - loss: 23.6512 - recon_loss: 15.3073
# Epoch 27: loss improved from 23.70879 to 23.69149, saving model to best_vae_weights.weights.h5
#
# Epoch 27: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.3547 - loss: 23.6915 - recon_loss: 15.3367 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 28/30
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3566 - loss: 23.6149 - recon_loss: 15.2582
# Epoch 28: loss improved from 23.69149 to 23.69124, saving model to best_vae_weights.weights.h5
#
# Epoch 28: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.3615 - loss: 23.6912 - recon_loss: 15.3298 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 29/30
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3571 - loss: 23.6162 - recon_loss: 15.2590
# Epoch 29: loss improved from 23.69124 to 23.64877, saving model to best_vae_weights.weights.h5
#
# Epoch 29: finished saving model to best_vae_weights.weights.h5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - kl_loss: 8.3531 - loss: 23.6488 - recon_loss: 15.2957 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 30/30
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - kl_loss: 8.3619 - loss: 23.6212 - recon_loss: 15.2593
# Epoch 30: loss did not improve from 23.64877
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - kl_loss: 8.3804 - loss: 23.6547 - recon_loss: 15.2743 - val_kl_loss: 0.0000e+00 - val_recon_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Restoring model weights from the end of the best epoch: 29.
# ✅ 최적 VAE 가중치가 best_vae.keras 에 저장됐습니다.

# %%
# ✅ VAE 학습 수렴 곡선
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Total Loss', color='purple')  # 'total_loss' → 'loss'
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.title('VAE – Total Loss'); plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['recon_loss'], label='Recon Loss', color='steelblue')
plt.plot(history.history['kl_loss'],    label='KL Loss',    color='darkorange')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.title('VAE – Recon vs KL Loss'); plt.legend()

plt.tight_layout(); plt.show()

# %% [markdown]
# **💡 VAE 손실은 두 가지로 구성됩니다.**
# - **Recon Loss**: 입력 이미지를 얼마나 정확하게 복원했는지 측정 (낮을수록 좋음)
# - **KL Loss**: 잠재 공간 분포가 표준 정규분포에 얼마나 가까운지 측정 (낮을수록 좋음)

# %% [markdown]
# ### 2-5. 재복원 결과 시각화

# %%
# 테스트 데이터 복원
decoded_imgs = vae.decoder(vae.encoder(x_test)[2])

n = 10
plt.figure(figsize=(20, 6))
for i in range(1, n + 1):
    # 원본 이미지
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28), cmap="gray")
    plt.axis("off")
    if i == 1:
        plt.title("Original")

    # 복원 이미지
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].numpy().reshape(28, 28), cmap="gray")
    plt.axis("off")
    if i == 1:
        plt.title("Reconstructed")
plt.show()

# %% [markdown]
# #### **💡 왜 AE보다 흐릿할까? VAE의 트레이드오프**
#
# AE는 **재구성 손실만** 최소화하기 때문에, 잠재 공간의 특정 좌표에 각 이미지를 정확히 고정시킬 수 있습니다.
# 반면 VAE는 재구성 손실에 더해 **KL 손실**로 잠재 공간을 정규분포 형태로 강제합니다.
#
# 이 과정에서 비슷한 이미지들의 잠재 벡터가 서로 겹치게 되고,
# 디코더는 **여러 이미지의 평균적인 모습**을 출력하게 됩니다 → **흐릿한 재구성**
#
# <br>
#
#
# | | AE | VAE |
# |--|----|----|
# | 재구성 품질 | ✅ 선명 | △ 흐릿 |
# | 새 이미지 생성 | ❌ 불가 | ✅ 가능 (`z ~ N(0,1)` 샘플링) |
# | 잠재 공간 | 비구조적 | 정규분포 구조 |
#
# <br>
#
# > **VAE의 흐릿함은 버그가 아니다!**
# > "새 이미지를 생성할 수 있는 능력"을 얻기 위해 재구성 품질을 일부 포기한 것!
#
# <br>
#
# 이 한계를 극복하기 위해 등장한 것이 **GAN**과 **Diffusion** 모델입니다.
# GAN은 판별자와의 경쟁을 통해, Diffusion은 노이즈 제거 과정을 통해 훨씬 선명한 이미지를 생성합니다.
#
# 실습해 봅시다!

# %% [markdown]
# ## 🔍 3. GAN
#
# 이번엔 생성자(Generator)와 판별자(Discriminator)를 번갈아 학습시켜 Fashion MNIST 의류 이미지를 새로 생성해봅시다.

# %% [markdown]
# ### 3-1. 데이터 준비

# %%
# Fashion MNIST 데이터 로드
(x_train, _), (_, _) = tf.keras.datasets.fashion_mnist.load_data()

# [0, 1] → [-1, 1] 스케일링 (GAN에서는 tanh 출력 맞추기 위함)
x_train = (x_train.astype(np.float32) - 127.5) / 127.5
x_train = np.expand_dims(x_train, axis=-1)

BUFFER_SIZE = 60000
BATCH_SIZE = 256

# tf.data로 배치 구성
train_dataset = tf.data.Dataset.from_tensor_slices(x_train).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# ### 3-2. 생성자(Generator) 모델 정의

# %%
def make_generator_model():
    model = tf.keras.Sequential([
        layers.Dense(7*7*256, use_bias=False, input_shape=(100,)),
        layers.BatchNormalization(),
        layers.LeakyReLU(),

        layers.Reshape((7, 7, 256)),

        layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False),
        layers.BatchNormalization(),
        layers.LeakyReLU(),

        layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False),
        layers.BatchNormalization(),
        layers.LeakyReLU(),

        layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh')
    ])
    return model

generator = make_*********_*****()  #위에서 정의한 생성자 함수!
generator.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 12544)          │     1,254,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 12544)          │        50,176 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 7, 7, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 7, 7, 128)      │       819,200 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 7, 7, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 14, 14, 64)     │       204,800 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 14, 14, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 28, 28, 1)      │         1,600 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,330,944 (8.89 MB)
#  Trainable params: 2,305,472 (8.79 MB)
#  Non-trainable params: 25,472 (99.50 KB)

# %% [markdown]
# ### 3-3. 판별자(Discriminator) 모델 정의

# %%
def make_discriminator_model():
    model = tf.keras.Sequential([
        layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same',
                      input_shape=[28, 28, 1]),
        layers.LeakyReLU(),
        layers.Dropout(0.3),

        layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'),
        layers.LeakyReLU(),
        layers.Dropout(0.3),

        layers.Flatten(),
        layers.Dense(1)
    ])
    return model

discriminator = make_*************_*****()  #위에서 정의한 판별자 함수!
discriminator.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 14, 14, 64)     │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 7, 7, 128)      │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │         6,273 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 212,865 (831.50 KB)
#  Trainable params: 212,865 (831.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 3-4. 손실함수 및 옵티마이저 설정

# %%
# ✅ 손실 함수 정의
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def generator_loss(fake_output):
    # 생성자는 판별자를 '진짜'라고 속여야 하므로 레이블 = 1
    return *****_entropy(tf.ones_like(fake_output), fake_output)

def discriminator_loss(real_output, fake_output):
    # 판별자는 진짜=1, 가짜=0 으로 분류해야 함
    real_loss = cross_entropy(tf.ones_like(real_output),  real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return ****_loss + ****_loss        # 총 손실은 두 손실의 합입니다!

# GAN 학습 안정화를 위해 beta_1=0.5 사용 (일반적인 GAN 권장 설정)
generator_optimizer     = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %% [markdown]
# ### 3-5. 학습 루프 정의

# %%
EPOCHS = 50
noise_dim = 100
num_examples_to_generate = 16

# 고정 시드(매번 같은 예시 생성)
seed = tf.random.normal([num_examples_to_generate, noise_dim])

@tf.function
def train_step(images):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator(noise, training=True)

        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss

def generate_and_save_images(model, epoch, test_input):
    predictions = model(test_input, training=False)
    fig = plt.figure(figsize=(4, 4))
    for i in range(predictions.shape[0]):
        plt.subplot(4, 4, i+1)
        plt.imshow(predictions[i, :, :, 0] * 0.5 + 0.5, cmap='gray')
        plt.axis('off')
    plt.suptitle(f'Epoch {epoch}', fontsize=14)
    plt.show()

# %% [markdown]
# ### 3-6. GAN 학습

# %%
# patience를 제거하고, 최적 가중치 복원도 제거
def train_gan(dataset, epochs):
    gen_losses, disc_losses = [], []

    for epoch in range(epochs):
        start = time.time()
        epoch_gen_losses, epoch_disc_losses = [], []

        for image_batch in dataset:
            gen_loss, disc_loss = train_step(image_batch)
            epoch_gen_losses.append(float(gen_loss))
            epoch_disc_losses.append(float(disc_loss))

        avg_gen  = sum(epoch_gen_losses)  / len(epoch_gen_losses)
        avg_disc = sum(epoch_disc_losses) / len(epoch_disc_losses)
        gen_losses.append(avg_gen)
        disc_losses.append(avg_disc)

        generate_and_save_images(generator, epoch + 1, seed)
        print(f'\nEpoch {epoch+1}, Gen Loss: {avg_gen:.4f}, Disc Loss: {avg_disc:.4f}')
        print(f'Time for epoch {epoch+1} is {time.time()-start:.2f} sec\n')

    return gen_losses, disc_losses

# %%
# 코랩 T4 기준 약 6분 정도 걸리는 코드입니다. 돌려놓고 화장실 갔다 오세요.

gen_losses, disc_losses = train_gan(train_dataset, epochs=30)
# Out:
# Epoch 1, Gen Loss: 1.0075, Disc Loss: 1.1162
# Time for epoch 1 is 14.69 sec
# Epoch 2, Gen Loss: 0.9654, Disc Loss: 1.1799
# Time for epoch 2 is 14.57 sec
# Epoch 3, Gen Loss: 0.9245, Disc Loss: 1.2084
# Time for epoch 3 is 14.24 sec
# Epoch 4, Gen Loss: 0.8728, Disc Loss: 1.2609
# Time for epoch 4 is 13.37 sec
# Epoch 5, Gen Loss: 0.8584, Disc Loss: 1.2592
# Time for epoch 5 is 13.08 sec
# Epoch 6, Gen Loss: 0.8402, Disc Loss: 1.2783
# Time for epoch 6 is 13.12 sec
# Epoch 7, Gen Loss: 0.8417, Disc Loss: 1.2742
# Time for epoch 7 is 13.49 sec
# Epoch 8, Gen Loss: 0.8505, Disc Loss: 1.2673
# Time for epoch 8 is 13.78 sec
# Epoch 9, Gen Loss: 0.8295, Disc Loss: 1.2786
# Time for epoch 9 is 13.78 sec
# Epoch 10, Gen Loss: 0.9082, Disc Loss: 1.2211
# Time for epoch 10 is 13.67 sec
# Epoch 11, Gen Loss: 0.8607, Disc Loss: 1.2583
# Time for epoch 11 is 14.33 sec
# Epoch 12, Gen Loss: 0.8336, Disc Loss: 1.2785
# Time for epoch 12 is 13.43 sec
# Epoch 13, Gen Loss: 0.8278, Disc Loss: 1.2797
# Time for epoch 13 is 13.44 sec
# Epoch 14, Gen Loss: 0.8267, Disc Loss: 1.2862
# Time for epoch 14 is 13.41 sec
# Epoch 15, Gen Loss: 0.8065, Disc Loss: 1.3059
# Time for epoch 15 is 13.41 sec
# Epoch 16, Gen Loss: 0.8052, Disc Loss: 1.3028
# Time for epoch 16 is 13.41 sec
# Epoch 17, Gen Loss: 0.7992, Disc Loss: 1.3101
# Time for epoch 17 is 13.43 sec
# Epoch 18, Gen Loss: 0.8093, Disc Loss: 1.3064
# Time for epoch 18 is 13.47 sec
# Epoch 19, Gen Loss: 0.7876, Disc Loss: 1.3154
# Time for epoch 19 is 13.57 sec
# Epoch 20, Gen Loss: 0.7845, Disc Loss: 1.3216
# Time for epoch 20 is 13.59 sec
# Epoch 21, Gen Loss: 0.8107, Disc Loss: 1.3002
# Time for epoch 21 is 14.45 sec
# Epoch 22, Gen Loss: 0.7813, Disc Loss: 1.3244
# Time for epoch 22 is 13.69 sec
# Epoch 23, Gen Loss: 0.7833, Disc Loss: 1.3240
# Time for epoch 23 is 13.65 sec
# Epoch 24, Gen Loss: 0.7816, Disc Loss: 1.3248
# Time for epoch 24 is 13.60 sec
# Epoch 25, Gen Loss: 0.7805, Disc Loss: 1.3263
# Time for epoch 25 is 13.56 sec
# Epoch 26, Gen Loss: 0.7872, Disc Loss: 1.3222
# Time for epoch 26 is 13.51 sec
# Epoch 27, Gen Loss: 0.7771, Disc Loss: 1.3247
# Time for epoch 27 is 13.53 sec
# Epoch 28, Gen Loss: 0.7878, Disc Loss: 1.3229
# Time for epoch 28 is 13.48 sec
# Epoch 29, Gen Loss: 0.7920, Disc Loss: 1.3182
# Time for epoch 29 is 13.50 sec
# Epoch 30, Gen Loss: 0.7788, Disc Loss: 1.3221
# Time for epoch 30 is 13.68 sec

# %%
# ✅ GAN 학습 수렴 곡선
plt.figure(figsize=(8, 4))
plt.plot(gen_losses,  label='Generator Loss',     color='steelblue')
plt.plot(disc_losses, label='Discriminator Loss', color='tomato', linestyle='--')
plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.title('DCGAN – Generator vs Discriminator Loss')
plt.legend(); plt.tight_layout(); plt.show()

# %% [markdown]
# **💡 GAN 손실 해석 포인트**
# - **이상적인 상태**: Gen Loss 와 Disc Loss 가 비슷한 수준에서 안정적으로 수렴
# - **Disc Loss → 0**: 판별자가 압도적으로 강해진 상태 → 생성자가 학습하지 못함
# - **Gen Loss → 0**: 생성자가 판별자를 완전히 속이는 상태 → Mode Collapse 위험

# %% [markdown]
# **💡 Generator Loss와 Discriminator Loss는 서로 비슷한 수준인 것이 가장 좋습니다!**

# %% [markdown]
# ### 3-7. 최종 이미지 생성

# %%
# 학습이 끝난 후 새로운 이미지를 생성
noise = tf.random.normal([25, noise_dim])
generated_images = *********(noise, training=False)   #생성자!

plt.figure(figsize=(5,5))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(generated_images[i, :, :, 0] * 0.5 + 0.5, cmap='gray')
    plt.axis('off')
plt.show()

# %% [markdown]
# **💡 첫 에포크에선 형편없는 가짜 이미지가 생성됩니다.**
#
# **그러나 30 에포크가 지나면 이미지가 그럴 듯한 의류 이미지를 생성하는 것을 볼 수 있습니다.**
#
# **더 많은 에포크를 지나 enerator Loss와 Discriminator Loss가 비슷하게 수렴하면 더욱 명확한 의류 이미지를 생성하겠죠?**

# %% [markdown]
# ## 🔍 4. Diffusion Model (확산 모형)

# %% [markdown]
# ### 4-1. 데이터 준비

# %%
transform = transforms.Compose([transforms.ToTensor()])
data = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(data, batch_size=64, shuffle=True)

# 샘플 하나 시각화
x0_sample = data[0][0]
plt.imshow(x0_sample.squeeze(), cmap='gray')
plt.axis('off')
plt.title("Original Fashion MNIST Image (x₀)")
plt.show()
# Out:
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 12.1MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 203kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.79MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 17.0MB/s]

# %% [markdown]
# ### 4-2. 순확산 (Forward Diffusion)

# %%
T = 300  # total diffusion steps
beta = torch.linspace(1e-4, 0.02, T).to(device)
alpha = 1 - beta
alpha_bar = torch.cumprod(alpha, dim=0)

# %%
# ✅ 배치 단위로 노이즈 추가
def add_noise(x0, t):
    noise = torch.randn_like(x0)
    sqrt_ab = torch.sqrt(alpha_bar[t]).view(-1, 1, 1, 1)    # 원본데이터(x0)에 곱해지는 가중치
    sqrt_1_ab = torch.sqrt(1 - alpha_bar[t]).view(-1, 1, 1, 1)    # 노이즈(noise)에 곱해지는 가중치
    return sqrt_ab * ** + sqrt_1_ab * *****   # 가중치에 원본데이터와 노이즈를 곱해줍시다!

# %%
# ✅ 순확산 시각화 (샘플 한 장)
x0 = x0_sample.unsqueeze(0).to(device)  # [1,1,28,28]
plt.figure(figsize=(12, 2))
for i, t in enumerate([0, 50, 100, 200, 299]):
    xt = add_noise(x0, torch.tensor([t], device=device))
    plt.subplot(1, 5, i + 1)
    plt.imshow(xt.squeeze().cpu(), cmap='gray')
    plt.axis('off')
    plt.title(f"t={t}")
plt.suptitle("Forward Diffusion: Adding Noise", y=1.05, fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# **💡 노이즈가 잘 추가된 것을 확인할 수 있습니다!**

# %% [markdown]
# ### 4-3. 역확산 (Reverse Diffusion)

# %%
# ✅ 타임스텝 임베딩을 사용하는 CNN 기반 denoiser
# 노이즈 제거는 타임스텝(t)에 따라 달라야 하므로 t 정보를 모델에 주입합니다.
class SimpleDenoiser(nn.Module):
    def __init__(self, T=300):
        super().__init__()
        self.T = T
        self.time_emb  = nn.Embedding(T, 64)
        self.time_proj = nn.Linear(64, 128)   # 32→64, 64→128

        self.enc1 = nn.Conv2d(1,   64,  3, padding=1)   # 32→64
        self.enc2 = nn.Conv2d(64,  128, 3, stride=2, padding=1)  # 64→128
        self.mid  = nn.Conv2d(128, 128, 3, padding=1)   # 추가: bottleneck
        self.dec1 = nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1)  # 128→64
        self.out  = nn.Conv2d(64, 1, 3, padding=1)      # 64→1

    def forward(self, x, t):
        t_emb = F.relu(self.time_proj(self.time_emb(t)))
        t_emb = t_emb.view(-1, 128, 1, 1)

        h1 = F.relu(self.enc1(x))    # [B, 64, 28, 28]
        h2 = F.relu(self.enc2(h1))   # [B, 128, 14, 14]
        h2 = h2 + t_emb             # 타임스텝 정보 주입
        h2 = F.relu(self.mid(h2))   # [B, 128, 14, 14] - bottleneck
        h3 = F.relu(self.dec1(h2))  # [B, 64, 28, 28]
        return torch.sigmoid(self.out(h3 + h1))  # skip connection

# %%
model = SimpleDenoiser(T=T).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)
loss_fn = nn.MSELoss()

# %%
# ✅ 역확산 (점진적 노이즈 제거) - 타임스텝 t를 모델에 전달
@torch.no_grad()
def reverse_diffusion(model, steps=10):
    x = torch.randn((1, 1, 28, 28), device=device)  # 완전 노이즈에서 시작
    images = [x.cpu()]
    for i in range(steps):
        t_val = max(0, T - 1 - i * (T // steps))
        t_tensor = torch.tensor([t_val], device=device)
        denoised = model(x, t_tensor)      # ✅ t 전달
        x = x - 0.3 * (x - denoised)       # 단순 denoising step
        images.append(x.cpu())
    return images

# %%
diff_losses    = []
best_diff_loss = float('inf')
best_diff_state = None

for epoch in range(25):
    epoch_losses = []
    for x_batch, _ in train_loader:
        x_batch = x_batch.to(device)
        t = torch.randint(0, T, (x_batch.size(0),), device=device)
        xt = add_noise(x_batch, t)
        pred = model(xt, t)
        loss = loss_fn(pred, x_batch)

        optimizer.zero_grad()
        loss.********()       #역전파
        optimizer.step()
        epoch_losses.append(loss.item())

    avg_loss = sum(epoch_losses) / len(epoch_losses)
    diff_losses.append(avg_loss)
    print(f'Epoch {epoch + 1}, loss = {avg_loss:.4f}')

    # 최적 가중치 저장
    if avg_loss < best_diff_loss:
        best_diff_loss  = avg_loss
        best_diff_state = copy.deepcopy(model.state_dict())

    # 5에폭마다 역확산 이미지 시각화
    if (epoch + 1) % 5 == 0:
        images = reverse_diffusion(model, steps=10)
        fig, axes = plt.subplots(1, len(images), figsize=(len(images) * 1.5, 2))
        for k, img in enumerate(images):
            axes[k].imshow(img.squeeze().numpy(), cmap='gray')
            axes[k].axis('off')
            axes[k].set_title(f's{k}', fontsize=7)
        plt.suptitle(f'Diffusion Epoch {epoch+1} – Reverse Process',
                     fontsize=11, fontweight='bold')
        plt.tight_layout()
        plt.show()

# 최적 가중치 복원
if best_diff_state is not None:
    model.load_state_dict(best_diff_state)
    print('✅ 최적 Diffusion 가중치 복원 완료')
# Out:
# Epoch 1, loss = 0.0539
# Epoch 2, loss = 0.0423
# Epoch 3, loss = 0.0400
# Epoch 4, loss = 0.0391
# Epoch 5, loss = 0.0384
# Epoch 6, loss = 0.0383
# Epoch 7, loss = 0.0379
# Epoch 8, loss = 0.0376
# Epoch 9, loss = 0.0375
# Epoch 10, loss = 0.0372
# Epoch 11, loss = 0.0370
# Epoch 12, loss = 0.0369
# Epoch 13, loss = 0.0367
# Epoch 14, loss = 0.0366
# Epoch 15, loss = 0.0368
# Epoch 16, loss = 0.0366
# Epoch 17, loss = 0.0366
# Epoch 18, loss = 0.0363
# Epoch 19, loss = 0.0363
# Epoch 20, loss = 0.0363
# Epoch 21, loss = 0.0363
# Epoch 22, loss = 0.0361
# Epoch 23, loss = 0.0362
# Epoch 24, loss = 0.0362
# Epoch 25, loss = 0.0361
# ✅ 최적 Diffusion 가중치 복원 완료

# %%
# ✅ Diffusion 학습 수렴 곡선
plt.figure(figsize=(8, 4))
plt.plot(diff_losses, label='Denoiser MSE Loss', color='mediumseagreen')
plt.xlabel('Epoch'); plt.ylabel('MSE Loss')
plt.title('Diffusion Denoiser – Training Loss Curve')
plt.legend(); plt.tight_layout(); plt.show()

# %% [markdown]
# **💡 Denoiser 손실이 낮을수록 노이즈 제거 성능이 향상됩니다.**
# 학습 과정에서 5에폭마다 역확산 이미지가 표시되어 품질 향상을 눈으로 확인할 수 있습니다.

# %%
# ✅ 역확산 시각화
images = reverse_*********(model, steps=10)     #위에서 정의한 역확산 함수!

plt.figure(figsize=(12, 2))
for i, img in enumerate(images):
    plt.subplot(1, len(images), i + 1)
    plt.imshow(img.squeeze(), cmap='gray')
    plt.axis('off')
    plt.title(f"Step {i}")
plt.suptitle("Reverse Diffusion: Denoising Process", y=1.05, fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# 확실히 에포크를 적게 돌려서 무슨 이미지를 만들어냈는지는 모르겠지만... 노이즈에서 무언가가 만들어졌습니다!

# %% [markdown]
# ## 수고하셨습니다~ AI 최적화로 넘어갑시다!
