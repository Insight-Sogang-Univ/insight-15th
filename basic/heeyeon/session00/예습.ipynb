# %% [markdown]
# # 1 <br>
# ## 판다스의 개념과 판다스 라이브러리를 불러오는 방법  <br>
# ### 판다스란 데이터를 표 형태로 다루는 라이브러리로, 데이터 분석과 전처리에 주로 사용.
# *import pandas as pd*
#
# ---
# # 2 <br>
# ## 데이터 프레임이란? <br>
# ### 행과 열로 이루어진 데이터 구조, 엑셀과 비슷
# ---
# # 3 <br>
# ## 데이터 확인, 추출, 조작 <br>
# *head(), tail(), describe()*
# *loc, iloc*
# ### 컬럼을 추가하거나, 수정, 삭제할 수 있다.
# *df[]=df[]+df[], df.drop('', axis=0, inplace=True), df.sort_values(by=''), df.set_index('')*
#
# ---
# # 4 <br>
# ## 집계함수 사용법 <br>
# ### *sum(), mean(), max(), count()*
# ---
