# %% [markdown]
# '''
# # EDA 개념 <br>
# >eda란, 데이터를 분석하기 전 구조를 파악하거나 분포를 보는 등, 분석의 방향을 설정하는 과정이다.
#
#
# ### *예시* **data.head():상위값 5개, data.info(): 열 별로 결측치 제외 개수 확인 etc**
# ---
# # 데이터셋 파악하기 <br>
# >데이터의 기본 구조와 특성을 본다. 절대경로과 상대경로의 구분.
# csv 파일: ,로 구분된 작은 데이터 형식.
#
# excel: 행과 열이 데이터프레임으로 대응
#
# ### *예시* **data.shape: 행, 열이 괄호 안에 제시됨 data.columns: 컬럼 확인 describe 등...**
# ---
# # 결측값 & 이상치 처리 <br>
# >결측값이란? 값이 없는 데이터
#
# *NaN, none*
#
#
# data.isnull() : True, False로 결측치를 확인해줌. 이후 data.dropna()로 True 결측치를 삭제해줌 (평균값, 최빈값 등으로도 대체 가능)
#
#
# >이상치란? 정상 범위를 벗어난 값
# 박스 플롯 시각화로 확인 가능 *sns.boxplt(data['age'])*  혹은 turkey Fences를 통해 사분위 범위 확인
# ---
# # 피처 엔지니어링 (변수 가공) <br>
# >모델 성능을 높이기 위해 새로운 변수 생성
# 변수 생성, 범주형 변수 변환, 구간화, 스케일링
# ---
# # 데이터 시각화 <br>
# >데이터를 그래프로 시각화하여 분석 이전 단계에 직관적 이해를 돕거나, 이상치를 발견하게 한다. 파라미터란 프로그래밍된 함수의 입력값
#
# *sns.hisplot(data['age'])*
#
# *sns.boxplot(x=data['age'])*
#
# '''
