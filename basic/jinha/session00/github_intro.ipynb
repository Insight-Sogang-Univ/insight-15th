# %% [markdown]
# ### 판다스랑 데이터프레임 오랜만이야

# %% [markdown]
# - 판다스의 개념과 판다스 라이브러리를 불러오는 방법에 대해 설명해주세요.
# - 데이터프레임이 무엇인지 정리해주세요.
# - 데이터를 확인, 추출, 조작하는 방법을 간단하게 작성해주세요.
# - 집계함수를 사용하는 방법을 쓰세요.

# %% [markdown]
# ## 판다스

# %% [markdown]
# - 데이터 분석에 특화된 파이썬 라이브러리
# - 행과 열로 이루어진 테이블 형태의 데이터 구조인 `DataFame`을 기본 틀로 사용

# %% [markdown]
# ### 판다스 라이브러리 불러 오기

# %% [markdown]
# import pandas as pd
#
# df=pd.read_csv('파일 경로')

# %% [markdown]
# ## 데이터프레임

# %% [markdown]
# - 컴퓨터로 정보를 정리하고 저장하는 도구
# - 판다스에서 사용하는 주요 데이터 구조

# %% [markdown]
# ### 데이터 확인

# %% [markdown]
# - head(), tail() 이용하여 일부 데이터 확인
# - df.shape, df.info(), df.describe(), df.isnull(), df.dtypes 등으로 데이터 정보 확인
# - df.count()로 데이터 개수 확인

# %% [markdown]
# ### 데이터 추출

# %% [markdown]
# - 인덱싱(Indexing), 슬라이싱(Slicing)
# - loc, iloc
# - 컬럼명으로 인덱싱
# - 불리언 인덱싱 등

# %% [markdown]
# ### 데이터 조작

# %% [markdown]
# - 데이터 추가, 삭제
# - 데이터 정렬 : df.sort_index(), df.sort_values(by="열 이름")
# - 데이터 변환 : astype, replace, transpose
# - 데이터 병합 : concat, merge

# %% [markdown]
# ## 집계함수

# %% [markdown]
# - df['컬럼 명'].mean() : 평균
# - df['컬럼 명'].median() : 중앙값
# - df['컬럼 명'].std() : 표준편차
# - df['컬럼 명'].sum() : 합계
# - df['컬럼 명'].max() : 최대값
# - df['컬럼 명'].min() : 최소값
