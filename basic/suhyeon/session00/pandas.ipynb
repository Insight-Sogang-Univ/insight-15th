# %%
import pandas as pd

pd.DataFrame()

pd.DataFrame(data = None, index = None, columns = None, dtype = None, copy = False)

lst = [['권도영', 19, '경영', '', '회장'], 
       ['방상운', 20, '화생공', '빅사', '교육팀장'],
       ['김태희', 24, '컴공', '', '교육팀원'], 
       ['박준상', 21, '경영', '빅사', '교육팀원'],
       ['최윤지', 23, '국문', '컴공', '교육팀원']]

df = pd.DataFrame(data = lst, columns=['이름', '학번', '전공', '복수전공', '역할'])
df = df.set_index('이름')

df

dic = {
    '이름': ['권도영', '방상운', '김태희', '박준상', '최윤지'],
    '학번': [19, 20, 24, 21, 23],
    '전공': ['컴공', '화생공', '컴공', '경영', '국문'],
    '복수전공': ['', '빅사', '', '빅사', '컴공'],
    '역할': ['회장', '교육팀장', '교육팀원', '교육팀원', '교육팀원']
}

df2 = pd.DataFrame(data = dic.key, columns = dic.values)
df2 = df2.set_index('이름')

df2

print(df)
print(df2)
