# %% [markdown]
# # 회귀 심화 과제

# %% [markdown]
# # House Sales in King Country, USA
#
# 먼저 선형 회귀분석을 복습해 봅시다.
# 선형 회귀분석을 사용하여 집값(price)을 예측해 봅시다.

# %% [markdown]
# **어떤 데이터 분석을 하더라도 가장 먼저 변수들을 살펴보고 시작해야 합니다.**
#
# 데이터셋에서 추출할 수 있는 변수는 다음과 같습니다.
#
# **독립 변수**
# - id : 고유한 id 값
# - date : 집이 매각된 날자
# - bedrooms : 침실 수
# - bathrooms : 욕실 수
# - sqft_living : 집의 평방 피트
# - sqft_lot : 부지의 평방 피트
# - floors : 집의 총 층수
# - waterfront : 물가가 보이는 집
# - condition : 상태가 얼마나 좋은지 여부
# - grade : 주택에 부여되는 등급
# - sqft_above : 지하실을 제외한 집의 평방 피트
# - sqft_basement : 지하실의 평방 피트
# - yr_built : 지어진 연도
# - yr_renovated : 리모델링된 연도
# - lat : 위도 좌표
# - long : 경도 좌표
# - sqft_living15 : 2015년 당시 거실 면적 (일부 개조를 의미하고, 부지 면적에 영향을 미칠 수도 있고 아닐 수도 있음)
# - sqft_lot15 : 2015년 당시 부지 면적(일부 개조를 의미함)
#
# **종속 변수**
# - price : 주택 가격

# %%
# 데이터 전처리 패키지
import numpy as np
import pandas as pd

# 통계학습 패키지
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

# 머신러닝 패키지
import sklearn.linear_model
from sklearn.model_selection import train_test_split

# 시각화 패키지
from matplotlib import pyplot as plt
import seaborn as sns

# 그래프를 실제로 그리기 위한 설정입니다
# %matplotlib inline

# 경고 메시지를 무시합니다
import warnings
warnings.filterwarnings('ignore')

# %%
# csv 파일을 불러와서 DataFrame 에 담습니다.
df = pd.read_csv('kc_house_data.csv')

# index를 1로 시작해보도록 수정합시다. 필수는 아니에요.
df.index += 1
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 1      7129300520  20141013T000000  221900.0         3       1.00
# 2      6414100192  20141209T000000  538000.0         3       2.25
# 3      5631500400  20150225T000000  180000.0         2       1.00
# 4      2487200875  20141209T000000  604000.0         4       3.00
# 5      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21609   263000018  20140521T000000  360000.0         3       2.50
# 21610  6600060120  20150223T000000  400000.0         4       2.50
# 21611  1523300141  20140623T000000  402101.0         2       0.75
# 21612   291310100  20150116T000000  400000.0         3       2.50
# 21613  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1             1180      5650     1.0           0     0  ...      7
# 2             2570      7242     2.0           0     0  ...      7
# 3              770     10000     1.0           0     0  ...      6
# 4             1960      5000     1.0           0     0  ...      7
# 5             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21609         1530      1131     3.0           0     0  ...      8
# 21610         2310      5813     2.0           0     0  ...      8
# 21611         1020      1350     2.0           0     0  ...      7
# 21612         1600      2388     2.0           0     0  ...      8
# 21613         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 1            1180              0      1955             0    98178  47.5112
# 2            2170            400      1951          1991    98125  47.7210
# 3             770              0      1933             0    98028  47.7379
# 4            1050            910      1965             0    98136  47.5208
# 5            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21609        1530              0      2009             0    98103  47.6993
# 21610        2310              0      2014             0    98146  47.5107
# 21611        1020              0      2009             0    98144  47.5944
# 21612        1600              0      2004             0    98027  47.5345
# 21613        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 1     -122.257           1340        5650
# 2     -122.319           1690        7639
# 3     -122.233           2720        8062
# 4     -122.393           1360        5000
# 5     -122.045           1800        7503
# ...        ...            ...         ...
# 21609 -122.346           1530        1509
# 21610 -122.362           1830        7200
# 21611 -122.299           1020        2007
# 21612 -122.069           1410        1287
# 21613 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %% [markdown]
# 기본적으로 다음 세 가지를 해 주시면 좋아요.
#
# 1. 결측치 확인
# 2. 각 column(변수)의 data type 학인
# 3. 기본적인 기술 통계값 확인

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# type 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 1 to 21613
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# 보통 `describe()` 를 통해 기본적인 기술 통계값을 확인할 수 있습니다.<br/>
# 여기서는 중간값, 결측치, 왜도, 첨도까지 보기 위해 다음과 같이 코드를 작성하겠습니다.

# %%
# 중간값, 결측치, 왜도, 첨도를 표시합니다.
df_stats = df.describe().T # 전치시키는 연산. 행과 열의 위치를 바꿔줘요. 

median_results = []
skew_results = []
kurtosis_results = []
null_results = []

for idx, val in enumerate(df_stats.index):
    median_results.append(df[val].median()) # 중간값 추가
    skew_results.append(df[val].skew()) # 왜도 추가
    kurtosis_results.append(df[val].kurtosis()) # 첨도 추가
    null_results.append(df[val].isnull().sum()) # 결측치 추가

df_stats['median'] = median_results
df_stats['missing'] = null_results
df_stats['skewness'] = skew_results
df_stats['kurtosis'] = kurtosis_results
df_stats
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# yr_built       21613.0  1.971005e+03  2.937341e+01  1.900000e+03
# yr_renovated   21613.0  8.440226e+01  4.016792e+02  0.000000e+00
# zipcode        21613.0  9.807794e+04  5.350503e+01  9.800100e+04
# lat            21613.0  4.756005e+01  1.385637e-01  4.715590e+01
# long           21613.0 -1.222139e+02  1.408283e-01 -1.225190e+02
# sqft_living15  21613.0  1.986552e+03  6.853913e+02  3.990000e+02
# sqft_lot15     21613.0  1.276846e+04  2.730418e+04  6.510000e+02
#
#                         25%           50%           75%           max  \
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# price          3.219500e+05  4.500000e+05  6.450000e+05  7.700000e+06
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.427000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068800e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747100e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222300e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05
#
#                      median  missing   skewness    kurtosis
# id             3.904930e+09        0   0.243329   -1.260542
# price          4.500000e+05        0   4.024069   34.585540
# bedrooms       3.000000e+00        0   1.974300   49.063653
# bathrooms      2.250000e+00        0   0.511108    1.279902
# sqft_living    1.910000e+03        0   1.471555    5.243093
# sqft_lot       7.618000e+03        0  13.060019  285.077820
# floors         1.500000e+00        0   0.616177   -0.484723
# waterfront     0.000000e+00        0  11.385108  127.632494
# view           0.000000e+00        0   3.395750   10.893022
# condition      3.000000e+00        0   1.032805    0.525764
# grade          7.000000e+00        0   0.771103    1.190932
# sqft_above     1.560000e+03        0   1.446664    3.402304
# sqft_basement  0.000000e+00        0   1.577965    2.715574
# yr_built       1.975000e+03        0  -0.469805   -0.657408
# yr_renovated   0.000000e+00        0   4.549493   18.701152
# zipcode        9.806500e+04        0   0.405661   -0.853479
# lat            4.757180e+01        0  -0.485270   -0.676313
# long          -1.222300e+02        0   0.885053    1.049501
# sqft_living15  1.840000e+03        0   1.108181    1.597096
# sqft_lot15     7.620000e+03        0   9.506743  150.763110

# %% [markdown]
# 이걸 보고 이런 생각을 하면 좋겠죠?
#
# 해당 결과값에서 종속 변수(타겟)인 `price`의 왜도(skewness)가 4.02로 왼쪽으로 치우쳐 있는 것을 확인할 수 있다.
# **자연로그를 활용하여 분포를 조정할 필요가 있겠다.**

# %%
df['price'].hist()
plt.show()

# %%
np.log(df['price']).hist()
plt.show()

# %%
np.log(df['price']).skew()
# Out:
# np.float64(0.4280724755759251)

# %% [markdown]
# 왜도가 4.02에서 0.42로 변한 것을 볼 수 있어요.

# %% [markdown]
# 자연로그를 취해서 종속 변수(price)의 분포가 정규분포 형태를 띄는 것을 확인할 수 있습니다(선형회귀분석 시 자연로그를 적용할 계획).
#
# 다음 함수를 통해 object 타입과 int64, float64 타입을 분류해서 데이터를 살펴봅시다.
# `df_obj.head()` 함수를 통해서 확인해보면 date의 전처리가 필요한 것을 알 수 있습니다.

# %%
def separate_dtype(DataFrame:df):
    df_obj = df.select_dtypes(include=['object'])
    df_numr = df.select_dtypes(include=['int64','float64'])
    return [df_obj, df_numr]

(df_obj, df_numr) = separate_dtype(df)

# %%
df_numr.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1  7129300520  221900.0         3       1.00         1180      5650     1.0
# 2  6414100192  538000.0         3       2.25         2570      7242     2.0
# 3  5631500400  180000.0         2       1.00          770     10000     1.0
# 4  2487200875  604000.0         4       3.00         1960      5000     1.0
# 5  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 1           0     0          3      7        1180              0      1955
# 2           0     0          3      7        2170            400      1951
# 3           0     0          3      6         770              0      1933
# 4           0     0          5      7        1050            910      1965
# 5           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 1             0    98178  47.5112 -122.257           1340        5650
# 2          1991    98125  47.7210 -122.319           1690        7639
# 3             0    98028  47.7379 -122.233           2720        8062
# 4             0    98136  47.5208 -122.393           1360        5000
# 5             0    98074  47.6168 -122.045           1800        7503

# %%
df_obj.head()
# Out:
#               date
# 1  20141013T000000
# 2  20141209T000000
# 3  20150225T000000
# 4  20141209T000000
# 5  20150218T000000

# %% [markdown]
# date column을 앞에서 4자리만 추출하고 type을 int64로 변경하고 column명을 date2로 저장할게요.

# %%
df_obj['date2'] = df_obj['date'].apply(lambda x: x[0:4])
df['date2'] = df_obj['date2'].astype('int64')
df['date2']
# Out:
# 1        2014
# 2        2014
# 3        2015
# 4        2014
# 5        2015
#          ...
# 21609    2014
# 21610    2015
# 21611    2014
# 21612    2015
# 21613    2014
# Name: date2, Length: 21613, dtype: int64

# %% [markdown]
# date2(집이 매각된 연도)와 yr_built(집이 지어진 연도)의 기간 차이를 비교해서 `sold-built_years`라는 새로운 변수를 추가합시다.

# %%
df['sold-built_years'] = df.apply(lambda x:((x['date2']) - (x['yr_built'])), axis=1)
df['sold-built_years']
# Out:
# 1        59
# 2        63
# 3        82
# 4        49
# 5        28
#          ..
# 21609     5
# 21610     1
# 21611     5
# 21612    11
# 21613     6
# Name: sold-built_years, Length: 21613, dtype: int64

# %% [markdown]
# 지금까지 데이터의 전체적인 파악 및 전처리를 했어요.</br>
# 이제 시작화를 통해 데이터의 특징을 살펴볼게요.
#
# 히스토그램을 통해 각각의 독립 변수 데이터의 분포를 확인할 수 있습니다.

# %%
df.hist(figsize=(22,18), density=True)
plt.show()

# %% [markdown]
# 종속 변수(price)와 선형 관계가 있을 것 같은 독립 변수들을 선정하여 산점도(Scatter plot) 그래프를 그려봅시다.

# %%
# 변수 선정
columns = ['price','bedrooms','sqft_living','waterfront','view','yr_built','sold-built_years','date2']

df_pairplot = df[columns]
sns.pairplot(df_pairplot)
plt.show()

# %% [markdown]
# 산점도를 통해서 종속 변수(price)와 독립 변수들 사이의 선형 관계를 대략적으로 파악할 수 있습니다.</br>
# 특히, 다른 변수들과는 달리 price와 sqft_living 간의 선형 관계를 볼 수 있죠.
#
# 히트맵(Heatmap)을 통해 종속 변수(price)와 상관관계가 높은 독립 변수들은 무엇인지 확인해볼게요.
#
# 그리고 독립 변수들 간에 상관관계가 높은 것들은 어떤 것인지 살펴봅니다.

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 1  7129300520  20141013T000000  221900.0         3       1.00         1180
# 2  6414100192  20141209T000000  538000.0         3       2.25         2570
# 3  5631500400  20150225T000000  180000.0         2       1.00          770
# 4  2487200875  20141209T000000  604000.0         4       3.00         1960
# 5  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 1      5650     1.0           0     0  ...              0      1955
# 2      7242     2.0           0     0  ...            400      1951
# 3     10000     1.0           0     0  ...              0      1933
# 4      5000     1.0           0     0  ...            910      1965
# 5      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  date2  \
# 1             0    98178  47.5112 -122.257           1340        5650   2014
# 2          1991    98125  47.7210 -122.319           1690        7639   2014
# 3             0    98028  47.7379 -122.233           2720        8062   2015
# 4             0    98136  47.5208 -122.393           1360        5000   2014
# 5             0    98074  47.6168 -122.045           1800        7503   2015
#
#    sold-built_years
# 1                59
# 2                63
# 3                82
# 4                49
# 5                28
#
# [5 rows x 23 columns]

# %%
# 반대쪽 삼각형은 안 보이게 설정합니다.
# fmt -> 실제 값 표시, .2f -> 소수점 둘째 자리까지 표현

df_corr = df.drop(columns=['date']).corr()
cmap = sns.diverging_palette(240, 10, n=9, as_cmap=True)

mask = np.zeros_like(df_corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(16,12))

sns.heatmap(df_corr, annot=True, mask=mask, cmap=cmap, linewidths=.5, fmt='.2f', annot_kws={"size":10})
plt.show() # 히트맵을 그립니다

# %% [markdown]
# price와 상관관계가 높은 변수들만 추려서 확인합니다. </br>
# 정렬을 이용하면 편리합니다.

# %%
df_corr.sort_values(by='price', ascending=False)[['price']]
# Out:
#                      price
# price             1.000000
# sqft_living       0.702035
# grade             0.667434
# sqft_above        0.605567
# sqft_living15     0.585379
# bathrooms         0.525138
# view              0.397293
# sqft_basement     0.323816
# bedrooms          0.308350
# lat               0.307003
# waterfront        0.266369
# floors            0.256794
# yr_renovated      0.126434
# sqft_lot          0.089661
# sqft_lot15        0.082447
# yr_built          0.054012
# condition         0.036362
# long              0.021626
# date2             0.003576
# id               -0.016762
# zipcode          -0.053203
# sold-built_years -0.053951

# %% [markdown]
# 독립 변수들 간의 상관관계를 확인해본 결과 </br>
# `sqft_living`, `sqft_above`, `sqft_living15`
# 세 변수들이 상관관계가 높게 나왔습니다.
#
# 세 변수들의 데이터 분포를 살펴볼게요.
#
# *(grade의 경우 최종 결정되는 '등급' 값이라 등급으로 가격을 예측하는 것은 무의미하다고 판단했습니다)*

# %%
# column 선택
columns = ['sqft_living', 'sqft_living15', 'sqft_above']
colors = ['blue','green','red']

living = df[columns]

# 한 번에 보기
plt.figure(figsize=(12,6))

for i in range(3):
    ax = sns.distplot(df[columns[i]], hist=True, norm_hist=False, kde=False, label=columns[i], color=colors[i])
ax.set(xlabel="sqft_living / sqft_living15 / sqft_above")

plt.legend()
plt.show()

# %% [markdown]
# 그림에서 볼 수 있듯이 세 변수들의 분포가 비슷하다는 것을 알 수 있어요.</br>
# 따라서 다중공선성이 존재할 경우 이 중 price와 상관관계가 가장 높은 sqft_living 으로 분석합니다.
#
# 설명 변수(X) 1개, 반응 변수(y) 1개일 때 사용하는 대표적인 방법론으로 단순선형회귀분석이 있죠?</br>
# 종속 변수(price)와 가장 상관관계가 높은 sqft_living 변수를 독립 변수로 단순선형회귀회석을 실시해봅시다.
#
# 설명 변수(X)를 sqft_living으로 하고 반응 변수(y)로 price를 했을 때 두 변수 간의 선형관계를 확인해봅시다.

# %%
sns.jointplot(x='sqft_living', y='price', data=df, kind='reg')
plt.show()

# %% [markdown]
# OLS를 이용해 회귀분석을 할 때는 항상 상수항을 추가해야 합니다.</br>
# add_constant 함수를 사용해서 상수항을 추가해 봅시다.

# %%
X = df[['sqft_living']]
y = df[['price']]

# 상수항을 추가합니다
X = sm.add_constant(X, has_constant="add")
X.head()
# Out:
#    const  sqft_living
# 1    1.0         1180
# 2    1.0         2570
# 3    1.0          770
# 4    1.0         1960
# 5    1.0         1680

# %% [markdown]
# fit() 함수를 통해 선형 모델에 적합시켜봅시다.
#
# 해당 결과를 result_model에 저장하고 summary() 함수를 통해서 결과를 확인합니다.

# %%
# 모델 fit
model = sm.OLS(y, X)
result_model = model.fit()
result_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.493
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                 2.100e+04
# Date:                Sun, 22 Mar 2026   Prob (F-statistic):               0.00
# Time:                        23:04:03   Log-Likelihood:            -3.0027e+05
# No. Observations:               21613   AIC:                         6.005e+05
# Df Residuals:                   21611   BIC:                         6.006e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -4.358e+04   4402.690     -9.899      0.000   -5.22e+04    -3.5e+04
# sqft_living   280.6236      1.936    144.920      0.000     276.828     284.419
# ==============================================================================
# Omnibus:                    14832.490   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           546444.713
# Skew:                           2.824   Prob(JB):                         0.00
# Kurtosis:                      26.977   Cond. No.                     5.63e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.63e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# 주요 항목별 세부 내용은 다음과 같다.
#
# - Dep. Variable : 종속 변수, 타겟값.
# - Model : 학습 모델 / OLS(Ordinary Least Squares), 잔차 제곱합(손실)을 최소로 하는 파라미터를 선택하는 방법
# - Method : Least Squares / 잔차 제곱합(손실)을 최소로 하는 파라미터를 선택하는 방법
# - No. Observation : 데이터셋 크기
# - Df Residuals : 데이터셋 크기 - 추정된 파라미터 수를 뺀 것
# - Df Model : 독립 변수의 숫자
# - Covariance Type : 공분산 종류(default: nonrobust)
# - R-squared : 결정계수, 모델의 설명력(0~1 사이 값), 1에 가까울수록 모델의 설명력이 높음
# - Adj. R-squared : 조정된 결정계수, 조정된 모델의 설명력
# - Std. error : 계수의 표준 오차
# - F-statistic : F value
# - Prob (F-statistic): p-value
# - Log-Likelihood : 최대 로그 우도
# - 아카이케 정보 기준(Akaike's Information Criterion; AIC) : 모델의 성능지표로 작을수록 좋은 모델
# - Coef : 계수값
# - P>|t| : p-value

# %% [markdown]
# P>|t|(p-value) 항목의 유의 확률이 유의 수준 0.05보다 훨씬 작아 유의 수준 0.05 이하에서 귀무 가설은 기각됩니다.
#
# 즉, 모형 통계학적 유의성이 확보됩니다.
#
# 시각화를 통해 실제 타겟값과 모델을 통해 추정한 값, 잔차(residual)를 확인해 봅시다.

# %%
# 잔차를 확인합니다
result_model.resid.plot()
plt.show()

# %% [markdown]
# # 다중 선형 회귀

# %% [markdown]
# 앞에서는 단순히 변수 하나만 가지고 단순 선형 회귀 모형을 돌렸습니다.
#
# 다중 선형 회귀 모형은 단순 선형 회귀모형의 확장으로, 연속형 반응변수 하나에 "설명 변수가 둘 이상"인 모형을 말합니다.
# 설명 변수가 늘어나므로 추가 검토해야 할 문제는 설명 변수 정보 중첩으로 발생하는 다중공선성(multicollinearlity) 문제와,
# 너무 많은 설명 변수를 포함해 발생하는 차원의 저주 문제 등이 있습니다.
#
# 이번에는 범주형 변수를 설명 변수로 포함한 회귀모형에 대해서도 논의할 거예요.

# %% [markdown]
# id를 제외한 모든 독립 변수를 사용해서 다중 선형 회귀분석을 합니다.
#
# 그 후 선별한 독립 변수들로 다시 다중 선형 회귀분석을 해 봅시다.
#
# >원래 뭐든 다 때려보고, 그 중 괜찮은 걸 고르는 것이 가장 속이 편합니다.

# %%
# date의 경우 전처리를 한 column이 존재하기 때문에 제외
columns = list(df.columns)
not_used = ['id','date']

for item in not_used:
    columns.remove(item)
columns
# Out:
# ['price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15',
#  'date2',
#  'sold-built_years']

# %%
# 위의 columns 만 선택한 df 선언
df_reg = df[columns]

# constant 더하고 feature columns 뽑아내기
df_kc_reg = sm.add_constant(df_reg, has_constant='add')
feature_columns = list(df_kc_reg.columns.difference(['price']))

# 변수 선택
X = df_kc_reg[feature_columns]
y = df_kc_reg.price

# 회귀 모형
multi_linear_model = sm.OLS(y, X)
result_model_1 = multi_linear_model.fit()

# 결과
result_model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.701
# Method:                 Least Squares   F-statistic:                     2816.
# Date:                Sun, 22 Mar 2026   Prob (F-statistic):               0.00
# Time:                        23:04:03   Log-Likelihood:            -2.9455e+05
# No. Observations:               21613   AIC:                         5.891e+05
# Df Residuals:                   21594   BIC:                         5.893e+05
# Df Model:                          18
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# bathrooms         4.125e+04   3245.693     12.710      0.000    3.49e+04    4.76e+04
# bedrooms         -3.598e+04   1887.302    -19.064      0.000   -3.97e+04   -3.23e+04
# condition         2.767e+04   2348.964     11.781      0.000    2.31e+04    3.23e+04
# const             -5.46e+07   6.59e+06     -8.282      0.000   -6.75e+07   -4.17e+07
# date2             1.938e+04   1952.649      9.926      0.000    1.56e+04    2.32e+04
# floors            7322.7479   3587.535      2.041      0.041     290.915    1.44e+04
# grade              9.61e+04   2147.594     44.750      0.000    9.19e+04       1e+05
# lat               6.053e+05   1.07e+04     56.511      0.000    5.84e+05    6.26e+05
# long             -2.147e+05   1.31e+04    -16.387      0.000    -2.4e+05   -1.89e+05
# sold-built_years    1.1e+04    976.502     11.265      0.000    9086.333    1.29e+04
# sqft_above          70.7670      2.248     31.481      0.000      66.361      75.173
# sqft_basement       39.8464      2.640     15.093      0.000      34.672      45.021
# sqft_living        110.6148      2.264     48.856      0.000     106.177     115.053
# sqft_living15       21.7694      3.439      6.330      0.000      15.028      28.511
# sqft_lot             0.1249      0.048      2.612      0.009       0.031       0.219
# sqft_lot15          -0.3794      0.073     -5.191      0.000      -0.523      -0.236
# view              5.251e+04   2135.068     24.596      0.000    4.83e+04    5.67e+04
# waterfront        5.837e+05   1.73e+04     33.705      0.000     5.5e+05    6.18e+05
# yr_built          8381.0897    977.491      8.574      0.000    6465.135    1.03e+04
# yr_renovated        20.7777      3.648      5.696      0.000      13.628      27.928
# zipcode           -582.8028     32.905    -17.712      0.000    -647.298    -518.307
# ==============================================================================
# Omnibus:                    18432.447   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1903378.131
# Skew:                           3.576   Prob(JB):                         0.00
# Kurtosis:                      48.414   Cond. No.                     6.19e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.72e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# 결과를 보면 모든 독립 변수들의 p>|t| (p-value) 유의 확률이 유의 수준 0.05보다 훨씬 작아 모형 통계학적 유의성이 확인됩니다.</br>
# R-squared 값이 0.701 로써 약 70%가 모형에 의해 설명된다는 것을 의미합니다.

# %% [markdown]
# 단순 선형 회귀와 달리 다중 선형 회귀분석에서는 모든 변수의 경우 **다중공선성(multicollinearlity)** 문제를 확인해야 한다.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

df_vif = pd.DataFrame()
df_vif["VIF"] = np.round([variance_inflation_factor(df_reg.values, i) for i in range(df_reg.shape[1])], 2)

df_vif["features"] = df_reg.columns
df_vif.sort_values(by='VIF', ascending=False)
# Out:
#            VIF          features
# 10         inf        sqft_above
# 11         inf     sqft_basement
# 19         inf             date2
# 12         inf          yr_built
# 20         inf  sold-built_years
# 3          inf       sqft_living
# 14  4922845.94           zipcode
# 16  1388182.32              long
# 15   159610.79               lat
# 9       162.17             grade
# 8        35.37         condition
# 2        28.83         bathrooms
# 17       27.87     sqft_living15
# 1        23.75          bedrooms
# 5        17.36            floors
# 0        10.56             price
# 18        2.61        sqft_lot15
# 4         2.38          sqft_lot
# 7         1.61              view
# 6         1.28        waterfront
# 13        1.20      yr_renovated

# %% [markdown]
# 설명 변수가 다수이기 때문에 모형에 포함된 설명 변수의 정보가 중첩(상관관계를 가짐)으로,
#
# **다중공선성 문제가 발생하는 것을 확인할 수 있습니다.**

# %% [markdown]
# 다음 독립 변수들을 임의로 선택해서 다중 선형 회귀분석을 실시해볼게요.
#
# 또한, 반응 변수(price)에 자연로그를 취해 비대칭인 데이터의 분포를 완화한 상태에서 회귀분석을 합니다.
#
# - bedrooms(연속형)
# - sqrt_living(연속형)
# - waterfront(범주형)
# - view(범주형)
# - sold-built_years : date - yr_built (연속형)

# %%
df_reg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 1 to 21613
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             21613 non-null  float64
#  1   bedrooms          21613 non-null  int64
#  2   bathrooms         21613 non-null  float64
#  3   sqft_living       21613 non-null  int64
#  4   sqft_lot          21613 non-null  int64
#  5   floors            21613 non-null  float64
#  6   waterfront        21613 non-null  int64
#  7   view              21613 non-null  int64
#  8   condition         21613 non-null  int64
#  9   grade             21613 non-null  int64
#  10  sqft_above        21613 non-null  int64
#  11  sqft_basement     21613 non-null  int64
#  12  yr_built          21613 non-null  int64
#  13  yr_renovated      21613 non-null  int64
#  14  zipcode           21613 non-null  int64
#  15  lat               21613 non-null  float64
#  16  long              21613 non-null  float64
#  17  sqft_living15     21613 non-null  int64
#  18  sqft_lot15        21613 non-null  int64
#  19  date2             21613 non-null  int64
#  20  sold-built_years  21613 non-null  int64
# dtypes: float64(5), int64(16)
# memory usage: 3.5 MB

# %%
df_reg = df[['bedrooms','sqft_living','waterfront','view','sold-built_years','price']]

df_kc_reg = sm.add_constant(df_reg, has_constant='add') # 상수항 추가
feature_columns = list(df_kc_reg.columns.difference(['price'])) # price를 제외한 feature 컬럼들만 뽑아냅니다.

X = df_kc_reg[feature_columns]
y = np.log(df_kc_reg.price)

# 회귀 모형
multi_linear_model = sm.OLS(y, X)
result_model_2 = multi_linear_model.fit()
result_model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.529
# Model:                            OLS   Adj. R-squared:                  0.529
# Method:                 Least Squares   F-statistic:                     4852.
# Date:                Sun, 22 Mar 2026   Prob (F-statistic):               0.00
# Time:                        23:04:06   Log-Likelihood:                -8675.5
# No. Observations:               21613   AIC:                         1.736e+04
# Df Residuals:                   21607   BIC:                         1.741e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# bedrooms            -0.0413      0.003    -12.647      0.000      -0.048      -0.035
# const               12.1722      0.011   1128.098      0.000      12.151      12.193
# sold-built_years     0.0025   8.96e-05     27.564      0.000       0.002       0.003
# sqft_living          0.0004   3.62e-06    117.929      0.000       0.000       0.000
# view                 0.0785      0.004     21.269      0.000       0.071       0.086
# waterfront           0.2885      0.031      9.285      0.000       0.228       0.349
# ==============================================================================
# Omnibus:                      190.066   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              215.753
# Skew:                          -0.183   Prob(JB):                     1.41e-47
# Kurtosis:                       3.325   Cond. No.                     2.88e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.88e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# 결과를 보면 모든 독립 변수들의 P >|t| (p-value) 유의 확률이 유의 수준 0.05보다 훨씬 작아 모형 통계학적 유의성이 확인되었습니다.
#
# 이제 다중공선성을 살펴봅니다.

# %%
vif_df = pd.DataFrame()
vif_df["feature"] = X.columns # X의 컬럼 리스트를 feature 이름으로 넣기
vif_df["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])] # 각 변수별 VIF 계산 (상수항 포함)

vif_df.sort_values(by='VIF', ascending=False).reset_index(drop=True)
# Out:
#             feature        VIF
# 0             const  19.251407
# 1       sqft_living   1.824667
# 2          bedrooms   1.523569
# 3              view   1.322623
# 4        waterfront   1.195014
# 5  sold-built_years   1.145203

# %% [markdown]
# 다중공선성 문제가 확실히 줄어들었음을 알 수 있습니다.

# %% [markdown]
# ### (참고) 읽어보세요~. 상수항을 포함하여 VIF를 계산한 까닭
# `statsmodels`의 `variance_inflation_factor()` 함수는 입력 데이터에 상수항이 들어있다고 가정하고 설계되었습니다.
# 상수항 없이 다중공선성을 계산하면 함수 내부적으로 계산되는 $R^2$가 비정상적으로 높게 측정돼서 실제로는 문제가 없는 변수인데도 VIF가 높게 나오는 현상이 발생할 수 있다고 합니다.

# %% [markdown]
# # 회귀모형의 가정 진단
#
# 회귀모형은 반응 변수와 설명 변수의 선형 관계를 전제로 합니다.</br>
# 또한 오차에 대한 독립성, 정규성, 등분산성 가정을 전제로 합니다.
#
# 앞서 확인한 모형의 유의성과 계수의 유의성이 확보되었다고 해도, **오차에 대한 가정을 만족하지 않으면** 다른 대안을 찾아야 해요.

# %% [markdown]
# ## 1. 선형성 검정

# %%
import matplotlib.pyplot as plt

fitted = result_model_2.fittedvalues

plt.scatter(fitted, y, alpha=0.5, label='Data')

# 대각선 추가
min_val = min(fitted.min(), y.min())
max_val = max(fitted.max(), y.max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='y = x')

plt.xlabel('Fitted values')
plt.ylabel('Actual values')
plt.title('Fitted vs Actual (Log Price)')
plt.legend()
plt.show()

# %% [markdown]
# 우상향하는 모습을 보이고, 데이터가 어느정도 대각선을 따라간다. <br>
# 데이터가 심하게 곡선으로 휘는 형태는 보이지 않으니까 선형성을 만족한다고 할 수 있다.

# %% [markdown]
# ## 2. 설명변수끼리의 독립성 검정
# 아까 위에서 했으니 생략할게요~

# %% [markdown]
# ## 3. 오차항의 평균이 0이다(근접한다).

# %%
# 잔차의 분포
resid = result_model_2.resid
sns.histplot(resid, kde=True, bins=30)
plt.title("Residuals Distribution")
plt.show()

# %% [markdown]
# 0 근처에 몰려 있는 걸 볼 수 있네요.
#
# t-test도 해봅시다.

# %%
# 귀무가설: 잔차의 평균은 0이다.
t_stat, p_val = stats.ttest_1samp(resid, 0)

print(f"t-통계량: {t_stat:.4f}")
print(f"p-value: {p_val:.4f}")
# Out:
# t-통계량: 0.0000
# p-value: 1.0000

# %% [markdown]
# 귀무가설을 기각하지 못했네요!

# %%
print(np.mean(resid))
# Out:
# 7.061413356091002e-12

# %% [markdown]
# e-12는 엄청나게 작은 숫자로 0에 가깝다고 볼 수 있습니다.

# %% [markdown]
# ## 4. 등분산성: 오차항의 분산이 일정해야 한다.

# %%
# 잔차 패턴 확인
fitted = result_model_2.predict()

resid = result_model_2.resid
pred = result_model_2.predict(X)

fig = plt.scatter(pred, resid, s=3)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Fitted values')
plt.ylabel('Residual')
plt.show()

# %%
from scipy.stats import levene

# 예측값(fitted values)의 중앙값을 기준으로 데이터를 두 그룹으로 나눕니다.
median_fitted = np.median(result_model_2.predict())
group1 = result_model_2.resid[result_model_2.predict() < median_fitted]
group2 = result_model_2.resid[result_model_2.predict() >= median_fitted]

# Brown-Forsythe는 levene 검정에서 center='median'을 사용해야 합니다.
stat, p = levene(group1, group2, center='median')

# Brown-Forsythe 검정의 귀무가설은 "두 그룹의 분산이 같다", 즉 "잔차의 분산이 일정하다"입니다.
print(f'Brown-Forsythe Statistic: {stat:.4f}, p-value: {p:.4f}')
# Out:
# Brown-Forsythe Statistic: 5.3742, p-value: 0.0204

# %% [markdown]
# 오차항의 분산 도표를 보면 분산의 정도가 일정하지 않다는 것을 느낄 수 있어요.
# Brown-Forsythe 검정에서도 p-value가 0.02이므로 귀무가설이 기각되고 대립가설이 채택되었네요.
# 따라서 해당 가정은 만족하지 못했습니다...
#
# 부동산 데이터의 경우, 데이터의 본질적인 특성 때문에 등분산성 가정을 완벽히 만족시키기는 어렵다고 합니다.
# 이상치 제거, 스케일링, 변수 변환 등을 통해 이분산성을 최대한 완화해 볼 수는 있지만, 교과서처럼 완벽한 등분산성을 100% 맞추는 것은 아주 어렵다고 하네요..

# %% [markdown]
# ## 5. 오차항은 자기상관되어 있지 않다.

# %%
# ACF (Auto-Correlation Function)
sm.graphics.tsa.plot_acf(result_model_2.resid)
plt.show()

# %%
from statsmodels.stats.stattools import durbin_watson

dw_stat = durbin_watson(result_model_2.resid)
print(f'Durbin-Watson stat: {dw_stat:.3f}')
# Out:
# Durbin-Watson stat: 1.956

# %% [markdown]
# ACF와 Durbin-Watson을 이용해 독립성 만족 여부를 확인할 수 있습니다.<BR>
# Durbin-Watson이 2에 가까우면 자기상관이 없다 -> 오차항은 자기상관 되어있지 않다

# %%
result_model_2.resid.plot()
plt.show()

# %% [markdown]
# ## 6. 정규성 검정

# %%
# Q-Q 도표
qqplot = sm.qqplot(result_model_2.resid, line="s")
plt.show()

# %%
# 샤피로-월크 검정
result_shapiro = stats.shapiro(result_model_2.resid)

print(f"F value : {result_shapiro[0]:.4f} / p-value : {result_shapiro[1]:.4f}")

if result_shapiro[1] < 0.05:
    print("p-value < 0.05 입니다.")
# Out:
# F value : 0.9959 / p-value : 0.0000
# p-value < 0.05 입니다.

# %%
# 관측치 개수 확인
print(f"관측치는: {len(result_model_2.resid)}")
# Out:
# 관측치는: 21613

# %% [markdown]
# H0 귀무가설: 데이터가 정규분포를 따른다<br>
# H1 대립가설: 데이터가 정규분포를 따르지 않는다. <br>
#
# 샤피로-윌크 검정에서는 p-value < 0.05인데<br>
# 이러면 귀무가설을 기각해서 '데이터가 정규분포를 따르지 않는다'가 결론이 돼야 하지 않나요??<br>
#
# 정답입니다!! <br>
# 샤피로-윌크 검정에서 p-value가 0.05보다 작으면 통계적으로는 정규성을 만족하지 않아요.
# 그런데, 이 경우는 관측치의 개수가 21613개죠.
# 이처럼 데이터가 많은 경우는 p-value 하나만 보고 정규성을 만족하지 않는다고 하기보다는 Q-Q 플롯을 같이 보면서 판단해야 해요.
# - 샤피로 윌크 검정은 데이터의 양이 많을 때 특잇값에 영향을 많이 받습니다.
# - 사소한 비정규 데이터에도 p-value를 매우 작게 계산하기 때문에 샤피로 윌크 검정만 하기보다는 Q-Q plot도 살펴봐야 해요.
#
# 위에서 봤을 때, Q-Q 플롯이 직선과 대체로 일치했죠! <BR>
# 그래서 이 경우는 정규성을 만족한다고 할 수 있어요.

# %% [markdown]
# #### (추가) 읽어보세요~
# 샤피로-윌크(Shapiro-Wilk) 같은 통계적 가설 검정은 샘플 사이즈에 매우 민감합니다.
# - 샘플 사이즈가 너무 클 때: 데이터가 정규분포와 아주 미세하게만 달라도 p-값이 0.05보다 작게 나와 정규성이 없다고 결론 내릴 수 있습니다.
#     - 샤피로 윌크 같은 통계 검정은 너무 예민해져 Q-Q plot을 통해 큰 규모를 전체적으로 판단하는 게 좋다고 합니다.
# - 샘플 사이즈가 너무 작을 때: 데이터가 정규분포와 꽤 차이가 나더라도 p-값이 0.05보다 크게 나와 정규성이 있다고 결론 내릴 수 있습니다.
#     - 시각적으로는 판단이 주관적일 수 있어서 통계 수치가 도움이 됩니다.

# %% [markdown]
# 비록 기본 가정 6가지 중 오차의 등분산성 가정을 완벽하게 만족하지는 못했지만, 'bedrooms', 'sqft_living', 'waterfront', 'view', 'sold-built_years'를 독립변수(X)로 구성한 다중선형회귀 모델은 집값(price, y)의 전반적인 추세를 파악하고 예측하는 데 있어 의미 있는 초기 베이스라인(Baseline) 모델로 충분히 활용할 수 있다는 것을 기억하시면 될 것 같아요!

# %% [markdown]
# **과제는 여기까지입니다! 수고하셨습니다~!**
