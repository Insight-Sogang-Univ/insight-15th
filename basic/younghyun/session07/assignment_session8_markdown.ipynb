# %% [markdown]
# # **연관 분석 & 경영 기초**

# %% [markdown]
# <p align="right">15기 손영현</p>

# %% [markdown]
# ---

# %% [markdown]
# # **연관 분석**

# %% [markdown]
# ## **1. 연관 분석**

# %% [markdown]
# ### 1) 연관 분석
# - 개념: 상품이나 서비스를 구매하는 등 일련의 거래나 사건 안에 존재하는 항목 간의 일정한 연관 규칙을 발견하는 분석
# ### 2) 연관규칙 분석
# - 형태: 'A를 구매하였을 때, B 또한 구매할 것이다'와 같이 if-then의 형식을 띄고, A+B로 표현됨.
#     - 조건절(Antecedent): '만일 ~라면'에 해당하는 부분
#     - 결과절(Consequent): 그 뒷부분에 해당하는 내용
#     - 아이템 집합(Item set): 조건절 또는 결과절을 구성하는 아이템들의 집합(상호 배반)
# - 상관관계를 파악할 뿐, 인과관계를 알 수 없음!

# %% [markdown]
# ## **2. 주요 개념**

# %% [markdown]
# ### 1) 적절한 연관규칙의 조건
# - 두 품목을 함께 구매한 경우의 수가 일정 수준 이상이어야 한다. -> 지지도
# - 품목 A를 포함하는 거래 중 품목 B를 구입하는 경우의 수가 일정 수준 이상이어야 한다. -> 신뢰도

# %% [markdown]
# **[지지도 Support]**
# - 전체 거래 항목 중 품목 A와 품목 B가 동시에 포함되는 거래의 비율
# <br>
# $지지도 = P(A \cap B)$

# %% [markdown]
# **[신뢰도 Confidence]**
# - 품목 A를 포함하는 거래 수 중 품목 A와 품목 B가 동시에 포함하는 거래의 비율
# <br>
# $신뢰도 = \frac{P(A \cap B)}{P(A)} = \frac{지지도}{P(A)}$

# %% [markdown]
# ### 2) 연관 분석의 평가 측도

# %% [markdown]
# **[향상도]**
# - 품목 A가 주어지지 않았을 때의 품목 B의 확률 대비, 품목 A가 주어졌을 때의 품목 B의 확률의 증가 비율
# <br>
# $향상도 = \frac{P(A \cap B)}{P(A)P(B)} = \frac{신뢰도}{P(B)}$

# %% [markdown]
# ## **3. 연관 분석 알고리즘**

# %% [markdown]
# ### 1) Apriori 알고리즘
# - 배경: 무차별 탐색의 비효율
# - 개념: 상위 조합에서부터 차례로 스캔하면서 특정 조합이 자주 발생하지 않는다면 이의 결과물로 탄생한 후속 조합들까지 모두 후보에서 배제하는 방식의 알고리즘
# - 하나의 조합만 검사하고도 이에서 파생된 다른 조합들까지 후보에서 배제할 수 있게 되므로 시간과 연산량을 효과적으로 줄일 수 있음.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 프로세스: 빈발 항목 집합을 찾고 → 단계적으로 조합을 생성하고 필터링
#     - 단일 항목 집합 생성
#     - 2개 항목 집합 생성
#     - 더 큰 항목 집합 생성
#     - 최종 빈발 항목 집합 선정

# %% [markdown]
# - 장점
#     - 수많은 상품 연관 구매 패턴 발견
#     - 원리가 간단하고 이해분석이 용이함.
# - 단점
#     - 여전히 데이터가 커질수록 속도가 느려짐.

# %% [markdown]
# ### 2) FP Growth 알고리즘
# - 배경: 여전히 느리다
# - 특징
#     - FP-Growth (Frequent Pattern Growth) 알고리즘은 빈발 품목 집합을 효율적으로 찾아냄.
#     - FP-Tree 라는 구조를 이용하여 Apriori를 효과적으로 구현함.
#     - Tree, Array, Linked_List를 합쳐놓은 구조!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 프로세스: 모든 항목의 빈도를 계산한 후, 최소 지지도 이상인 항목만을 남김.
#     - 데이터셋 확인
#     - 빈도순 재정렬
#     - FP-트리 생성
#     - 빈발 항목 집합 추출
#     - 연관 규칙 도출

# %% [markdown]
# - 장점
#     - 데이터를 두 번만 스캔하는 Tree 구조이기 때문에 Apriori보다 훨씬 빠름.
#     - 후보 itemlist를 생성할 필요없이, tree만 구성하면 끝임.
# - 단점
#     - 대용량 데이터셋에서 메모리를 효율적으로 사용하지 않음.
#     - Apriori에 비해 설계하기 어렵고, 지지도의 계산은 무조건 FP-Tree가 만들어져야 가능함.

# %% [markdown]
# ---

# %% [markdown]
# # **경영 기초**

# %% [markdown]
# ## **1. 문제 정의와 구조화**

# %% [markdown]
# ### 1) 문제 정의
# - 문제: 현재의 상태와 바라는 상태 사이의 격차

# %% [markdown]
# | SMART 원칙 | 특징 | 의미 |
# |---|---|---|
# | Specific | 구체적이고 범위가 명확함 | 무엇을, 어디까지 풀지 명확하게 정의 |
# | Measurable | 수치로 측정 가능함 | 성공 여부를 숫자로 판단 가능 |
# | Action-oriented | 실행 지향적 / 결과 중심적 | 행동을 이끌어내고 성과에 집중함 |
# | Relevant | 관련성 | 조직의 목표와 관련이 있어야 함 |
# | Time-bound | 시한성 (Time-bound) | 마감 기한과 의사결정 시점이 존재함 |

# %% [markdown]
# ### 2) 문제 구조화
# **[MECE]** -> 문제를 쪼갤 때 반드시 지켜야 할 철칙
# - Mutually Exclusive (상호 배타적): 겹치는 부분이 없어야 함. (중복 방지)
# - Collectively Exhaustive (전체 포괄적): 누락된 부분이 없어야 함. (누락 방지)
# - 좋은 MECE를 하기 위한 몇 가지 규정
#     - 논리적 일관성: 한 층위에서는 하나의 기준으로만 나눠야 함.
#     - 통찰력: 문제를 해결하는 데 도움이 되는 기준으로 나눠야 함.
#     - 상호 배타성: 조각들이 서로 겹치지 않아야 분석 결과가 명확함.

# %% [markdown]
# ## **2. 지표**

# %% [markdown]
# ### 1) 지표
# - 지표: 방향이나 목적, 기준 따위를 나타내는 표지
# <br>
# $\text{metrics} = \frac{\text{numerator}}{\text{denominator}}$

# %% [markdown]
# | 기능 | 효율성 지표 (Output ÷ Input) | 효과성 지표 (Actual ÷ Target) | 수익성/가치 지표 (Profit ÷ Resource) | 성장성/안정성 지표 |
# |---|---|---|---|---|
# | 재무 | 자산회전율 = 매출액 ÷ 총자산 | 예산 집행률 = 실제 지출 ÷ 계획 지출 | ROE = 순이익 ÷ 자기자본<br>ROA = 순이익 ÷ 자산 | 매출 성장률, 부채비율 |
# | 마케팅 | CAC 효율 = 신규고객 수 ÷ 마케팅비 | 전환율 = 구매자 ÷ 방문자 | 마케팅 ROI = 캠페인 이익 ÷ 캠페인 비용 | 시장점유율 성장률 |
# | HR (인사) | 노동생산성 = 산출량 ÷ 인력투입 | 교육 효과 달성률 = 실제 역량향상 ÷ 목표 역량향상 | HR ROI = 교육 후 성과 증가 ÷ 교육비 | 이직률, 직원 유지율 |
# | 운영 | 설비가동률 = 실제 가동시간 ÷ 총 가능시간 | 품질목표 달성률 = 합격품 ÷ 목표 품질수준 | 단위당 원가 절감율 = 절감액 ÷ 총원가 | 재고회전율, 공급망 안정성 |

# %% [markdown]
# ### 2) 지표를 정의하기
# - Proxy Metric: 활성화와 인게이지와 같이 추상적이여서 프로덕트마다 나름의 가정과 정의, 논의가 필요한 지표

# %% [markdown]
# ### 3) 북극성 지표 L1/L2 Metrics
# - 북극성 지표: 기업이 가장 중요하게 생각하는 지표
# - L1: 전사적인, 고수준의 성과 지표(전략 관점)
# - L2: L1 지표의 세부 사항을 측정하는 지표(전술 관점)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4) AARRR (해적 지표)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **1. Acquisition**
# - 사용자 획득, 즉 사용자가 여러 채널을 통해 여러분의 앱 혹은 웹사이트에 방문하는 것
# - 어떤 제품인지에 따라 고객 획득을 측정하는 기준이 달라지지만, 대체로 조회수, 가입 사용자 수 등 지표를 통해 측정함.
#     - CAC (Customer Acquisition Cost): 유저 획득 비용
#     - CTR (Cost Per Click): 클릭 한 건당 얼마 지출
#     - CPC (Cost Per Install): 인스톨 당 과금되는 상품
#     - CPL (Cost Per Lead): 유저 행동 당 드는 비용
#     - ROAS (Return On Ads Spending): 광고로 인한 매출액/광고비

# %% [markdown]
# **2. Activation**
# - 사용자 활성화란 사용자가 앱 또는 웹사이트에 첫 방문하여 주요 기능을 직접 사용하는 것을 의미함.
# - 제품의 성격에 따라 다양한 기준으로 측정됨.
#     - Sign-up: 유저가 제품에 들어온 시점
#     - Setup Moment: 유저가 제품의 핵심가치를 경험할 준비 완료
#     - A-HA! Moment: 유저가 핵심가치를 처음 경험한 순간
#     - Habit Moment: 유저가 제품 사용에 대한 습관 형성

# %% [markdown]
# **3. Retention**
# - 유지 단계에서는 신규 사용자를 장기 사용자로 전환시키는 것에 초점을 맞춤.
# - 어떻게 장기 고객을 양성할 것인지, 또 어떻게 고객의 지속적인 구매 행위를 증가시킬 수 있을지 고민해봐야 함.
#     - DN Retention: N일 안으로 재접속하는 경우
#     - MAU/DAU/WAU: 일/주/월마다 방문하는 횟수
#     - Stickness(DAU, MAU): 해당기간 동안 활성화 수 (*점성)

# %% [markdown]
# **4. Revenue**
# - 수익 단계에서는 사용자가 여러분의 제품 혹은 서비스를 유료 구매하기로 결정한 단계임.
# - 이 단계의 측정 지표 역시 제품 성격에 따라 달라질 수 있음.
# - 고객의 평생 가치(LTV)를 지속적으로 높여 나가고, 고객 유치 비용은 계속해서 줄여나가야 함.
#     - PU(Paying User): 전체 사용자 중에 결제를 한 사용자 비율
#     - Average Check: 구매 1회당 평균 금액 (Revenue/Transaction)
#     - ARPU(Average Revenue Per User): 인당 평균 매출
#     - ARPPU(Average Revenue Per Paying User): 결제자당 평균 매출
#     - LTV(Life Time Value): 유저가 진입부터 이탈까지 누적 수익

# %% [markdown]
# **5. Referral**
# - ‘어떻게 충성도 높은 사용자를 보이지 않는 브랜드 홍보자로 만들 것’이며, 또 ‘어떻게 제품을 잠재 고객들에게 추천하도록 만들 것’인가를 고민해봐야 함.
#     - 바이럴 계수: 기존 고객 한명당 데리고 온 새로운 고객의 수(1이 넘으면 Acquisition 단계를 하지 않아도 서비스가 성장)
#     - 바이럴 주기: 기존 고객 1명이 새로운 고객을 데려오는데 걸리는 시간

# %% [markdown]
# ## **3. 지표 분석 방법**

# %% [markdown]
# ### 1) 코호트(Cohort) 분석
# - 코호트(Cohort): 동질 집단(정의된 시간 범위 내에서 공통된 특성이나 경험을 공유하는 사용자 집단)
# - 분석 전에 데이터 세트의 데이터를 관련 그룹으로 나누는 일종의 행동 분석
# - 시간(날짜)에 기반하는 사용자 세그먼트를 분류한다고 이해

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **세로축(노란색) 방향: 코호트별 비교**
#     - 같은 기간이 지난 후 cohort 간 리텐션을 비교할 수 있음
#         - ex) 신규 유저 가입자는 점점 증가하는 추세
# - **대각선(빨간색) 방향: 시점별 비교**
#     - ex) [다른 예시] 2023년 3월부터 2024년 1월까지 보았을 때, 전반적인 고객들의 구매율이 점점 떨어지고 있음을 확인할 수 있음.
# - **가로축(보라색) 방향: 시간의 경과에 따른 변화 관찰**
#     - ex) 첫 방문(가입) 이후 시간이 경과할수록 앱 활성률은 떨어짐
# - 가입자는 느는데, 사람들이 잘 안 쓰네?
#
#     : **Acquisition**은 잘 작동하는데 **Activation&Retention**의 문제네?

# %% [markdown]
# ### 2) 퍼널(Funnel) 분석
# - 유저가 접속해서 떠날 때까지 유저의 행동을 추적함.
# - 소위 ‘깔때기’라고 불리며, 아래로 갈수록 점점 좁아짐. (시간이 지날수록 유저들은 이탈하기 때문)
# - 개선 방법 예시
#     1. 유입률(Acquisition) 높이기
#     2. 전환율(Activation) 높이기
#     3. 퍼널 단계 없애기
#     4. 퍼널 순서 바꾸기
#     5. 퍼널 단계 추가하기
#     6. 코호트로 나누어 보기
